# %%
from pathlib import Path
base_dir = Path("/data1/ujiie/shinra/EN/linkjp-sample-210315")

# %%
import json
import csv
category = "Airport"

def load_title_id(path):
    id2title = {}
    with open(path, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            id2title[row[0]] = row[1]
    return id2title

def load_annotation(path):
    annotation = []
    with open(path, "r") as f:
        for line in f:
            line = line.rstrip()
            if not line:
                continue
            line = json.loads(line)
            annotation.append(line)
    return annotation
            
def load_plain(path):
    plain_data = {}
    for fn in path.glob("*.txt"):
        page_id = fn.stem
        plain_data[page_id] = []
        with open(fn, "r") as f:
            for line in f:
                line = line.rstrip()
                plain_data[page_id].append(line)
    return plain_data

def extract_context(annotation, plain_data, id2title):
    dataset = []
    for ann in annotation:
        assert ann['page_id'] in plain_data
        doc = plain_data[ann['page_id']]
        mention = ann['text_offset']['text']
        start_line, start_off = ann['text_offset']['start']['line_id'], ann['text_offset']['start']['offset']
        end_line, end_off = ann['text_offset']['end']['line_id'], ann['text_offset']['end']['offset']
        
        if start_line == end_line:
            doc_mention = doc[start_line][start_off:end_off]
            right_context = doc[start_line][:start_off]
            left_context = doc[start_line][end_off:]
        else:
            doc_mention = doc[start_line][start_off:] + doc[end_line][:end_off]
            right_context = doc[start_line][:start_off]
            left_context = doc[end_line][end_off:]
        assert doc_mention == mention
        dataset.append([left_context, mention, right_context, ann["link_page_id"]])
    return dataset

def load_dataset(base_dir, category):
    id2title = load_title_id("/data1/ujiie/wiki_resource/title_id.csv")
    annotation = load_annotation(base_dir / "link_annotation" / f"{category}.json")
    plain_data = load_plain(base_dir / "plain" / category)
    dataset = extract_context(annotation, plain_data, id2title)
    return dataset

load_dataset(base_dir, "Airport")
# Out:
# [['',
#   'Port lotniczy im. Ignacego Jana Paderewskiego Bydgoszcz-Szwederowo',
#   '\t\t\t\tブィドゴシュチュ・イグナツィ・ヤン・パデレフスキ空港',
#   '3054905'],
#  ['）は、ポーランドのブィドゴシュチュの中心地から約3.5kmに位置する空港。2011年には約28万人の旅客を取り扱い、ポーランド内で9位の規模。',
#   'Port lotniczy im. Ignacego Jana Paderewskiego Bydgoszcz-Szwederowo',
#   'ブィドゴシュチュ・イグナツィ・ヤン・パデレフスキ空港（ポーランド語: ',
#   '3054905'],
#  ['所在地', 'ポーランド', 'ポーランドの旗 ', '6355'],
#  ['のブィドゴシュチュの中心地から約3.5kmに位置する空港。2011年には約28万人の旅客を取り扱い、ポーランド内で9位の規模。',
#   'ポーランド',
#   'ブィドゴシュチュ・イグナツィ・ヤン・パデレフスキ空港（ポーランド語: Port lotniczy im. Ignacego Jana Paderewskiego Bydgoszcz-Szwederowo）は、',
#   '6355'],
#  ['内で9位の規模。',
#   'ポーランド',
#   'ブィドゴシュチュ・イグナツィ・ヤン・パデレフスキ空港（ポーランド語: Port lotniczy im. Ignacego Jana Paderewskiego Bydgoszcz-Szwederowo）は、ポーランドのブィドゴシュチュの中心地から約3.5kmに位置する空港。2011年には約28万人の旅客を取り扱い、',
#   '6355'],
#  ['種類', 'ブィドゴシュチュ', '', '613752'],
#  ['Hua Hin Airport', 'ท่าอากาศยานหัวหิน', '\t\t\t\tフワヒン空港', '3254170'],
#  ['', 'Hua Hin Airport', '\t\t\t\tフワヒン空港ท่าอากาศยานหัวหิน', '3254170'],
#  [' 、英語\xa0: Hua Hin Airport ）は、タイ王国中部、プラチュワップキーリーカン県フワヒン郡フワヒン町にある空港。',
#   'ท่าอากาศยานหัวหิน',
#   'フワヒン空港（フワヒンくうこう、タイ語\xa0: ',
#   '3254170'],
#  [' ）は、タイ王国中部、プラチュワップキーリーカン県フワヒン郡フワヒン町にある空港。',
#   'Hua Hin Airport',
#   'フワヒン空港（フワヒンくうこう、タイ語\xa0: ท่าอากาศยานหัวหิน 、英語\xa0: ',
#   '3254170'],
#  ['所在地', 'タイ王国', 'タイ王国の旗 ', '52745'],
#  ['中部、プラチュワップキーリーカン県フワヒン郡フワヒン町にある空港。',
#   'タイ王国',
#   'フワヒン空港（フワヒンくうこう、タイ語\xa0: ท่าอากาศยานหัวหิน 、英語\xa0: Hua Hin Airport ）は、',
#   '52745'],
#  ['フワヒン郡フワヒン町種類', 'プラチュワップキーリーカン県', '', '104325'],
#  ['種類', 'フワヒン郡フワヒン町', 'プラチュワップキーリーカン県', '380205'],
#  ['にある空港。',
#   'プラチュワップキーリーカン県フワヒン郡フワヒン町',
#   'フワヒン空港（フワヒンくうこう、タイ語\xa0: ท่าอากาศยานหัวหิน 、英語\xa0: Hua Hin Airport ）は、タイ王国中部、',
#   '380205'],
#  ['（のちの西宮市枝川町）に存在していた大日本帝国海軍の飛行場である。また川西航空機（現・新明和工業）が製造する軍用機の試験飛行用も兼ねていた。',
#   '兵庫県武庫郡鳴尾村',
#   '鳴尾飛行場（なるおひこうじょう）は、かつて',
#   '1733053'],
#  ['）に存在していた大日本帝国海軍の飛行場である。また川西航空機（現・新明和工業）が製造する軍用機の試験飛行用も兼ねていた。',
#   '西宮市枝川町',
#   '鳴尾飛行場（なるおひこうじょう）は、かつて兵庫県武庫郡鳴尾村（のちの',
#   '18849'],
#  ['',
#   'Guiyang Longdongbao International Airport',
#   '\t\t\t\t貴陽竜洞堡国際空港',
#   '1906966'],
#  ['として開港する。', '貴陽竜洞堡空港', '1997年5月28日\u3000', '1906966'],
#  ['所在地', '中国', '中華人民共和国の旗 ', '1903'],
#  ['貴州省貴陽市南明区に位置する国際空港。貴陽市中心部から約12kmに位置し、貴州航空、華夏航空が当空港をハブ空港としている。',
#   '中華人民共和国',
#   '貴陽竜洞堡国際空港（きようりゅうとうほうこくさいくうこう）は',
#   '1903'],
#  ['種類', '貴州省貴陽市南明区', '', '1610750'],
#  ['に位置する国際空港。貴陽市中心部から約12kmに位置し、貴州航空、華夏航空が当空港をハブ空港としている。',
#   '貴州省貴陽市南明区',
#   '貴陽竜洞堡国際空港（きようりゅうとうほうこくさいくうこう）は中華人民共和国',
#   '1610750'],
#  ['', 'Yola Airport', '\t\t\t\tヨラ空港', '3053562'],
#  ['所在地', 'ナイジェリア', 'ナイジェリアの旗 ', '5116'],
#  ['のアダマワ州州都ヨラにある空港。', 'ナイジェリア', 'ヨラ空港（Yola Airport）は、', '5116'],
#  ['種類', 'ヨラ', '', '2398862'],
#  ['にある空港。', 'アダマワ州州都ヨラ', 'ヨラ空港（Yola Airport）は、ナイジェリアの', '2398862'],
#  ['', 'فرودگاه بین\u200cالمللی تبریز', '\t\t\t\tタブリーズ国際空港', '661173'],
#  ['\u200e、英語: Tabriz International Airport）は、イラン北部の東アゼルバイジャン州タブリーズにある国際空港。',
#   'فرودگاه بین\u200cالمللی تبریز',
#   'タブリーズ国際空港（ペルシア語: ',
#   '661173'],
#  ['）は、イラン北部の東アゼルバイジャン州タブリーズにある国際空港。',
#   'Tabriz International Airport',
#   'タブリーズ国際空港（ペルシア語: فرودگاه بین\u200cالمللی تبریز\u200e、英語: ',
#   '661173'],
#  ['所在地', 'イラン', '25x20px\xa0', '102'],
#  ['種類', '東アゼルバイジャン州タブリーズ', '', '226361'],
#  ['にある国際空港。',
#   'イラン北部の東アゼルバイジャン州タブリーズ',
#   'タブリーズ国際空港（ペルシア語: فرودگاه بین\u200cالمللی تبریز\u200e、英語: Tabriz International Airport）は、',
#   '226361'],
#  ['', 'Fukuoka Airport', '\t\t\t\t福岡第一飛行場', '1433805'],
#  ['。最盛期には大日本航空によって朝鮮、台湾、中華民国、東南アジアへの路線も開設され、戦前における日本最大の民間国際空港であった。',
#   '雁ノ巣飛行場',
#   '福岡第一飛行場（ふくおかだいいちひこうじょう）はかつて航空局が福岡県糟屋郡和白村（現在の福岡市東区）雁ノ巣に設置した飛行場。通称',
#   '1433805'],
#  ['」（Brady Air Base、施設番号・FAC 5006）の名称で主に輸送部隊の飛行場として使用されたが、1961年（昭和36年）の日米合同委員会でキャンプ博多・ブレディ飛行場・西戸崎通信施設の三施設を統合し、「雁ノ巣空軍施設」（Gannosu Air Station、施設番号・FAC 5005）として在日米軍に提供することが合意された。また、朝鮮戦争後は一時的措置として自衛隊が落下傘降下訓練に使用したほか、西日本空輸や福岡県警などのレシプロ機やヘリコプターが滑走路や格納庫の一部を共同使用していた。1965年（昭和40年）から飛行場区域内に通信傍受用の大型アンテナとオペレーション施設の建設が始まり、共同使用の停止とともに滑走路の舗装が撤去されたため、事実上飛行場としての機能は終焉した。通信施設は1966年（昭和41年）2月に完成し、第14陸軍保安局フィールドステーション（14th U.S. Army Security Agency Field Station）、海軍保安群博多部隊（Naval Security Group Activity, Hakata）、空軍第6918保安中隊（Air Force Security Service 6918th Security Squadron）などアメリカ3軍の諜報部隊が共同で北朝鮮方面の軍事（電波）情報の収集・分析活動を行っていたが、アメリカの国防予算と海外展開兵力の削減によって施設は閉鎖され、飛行場部分は1972年（昭和47年）、雁ノ巣空軍施設全域は1977年（昭和52年）に返還された。',
#   'ブレディ飛行場',
#   '戦後はアメリカ軍に接収され「',
#   '1433805'],
#  ['、施設番号・FAC 5006）の名称で主に輸送部隊の飛行場として使用されたが、1961年（昭和36年）の日米合同委員会でキャンプ博多・ブレディ飛行場・西戸崎通信施設の三施設を統合し、「雁ノ巣空軍施設」（Gannosu Air Station、施設番号・FAC 5005）として在日米軍に提供することが合意された。また、朝鮮戦争後は一時的措置として自衛隊が落下傘降下訓練に使用したほか、西日本空輸や福岡県警などのレシプロ機やヘリコプターが滑走路や格納庫の一部を共同使用していた。1965年（昭和40年）から飛行場区域内に通信傍受用の大型アンテナとオペレーション施設の建設が始まり、共同使用の停止とともに滑走路の舗装が撤去されたため、事実上飛行場としての機能は終焉した。通信施設は1966年（昭和41年）2月に完成し、第14陸軍保安局フィールドステーション（14th U.S. Army Security Agency Field Station）、海軍保安群博多部隊（Naval Security Group Activity, Hakata）、空軍第6918保安中隊（Air Force Security Service 6918th Security Squadron）などアメリカ3軍の諜報部隊が共同で北朝鮮方面の軍事（電波）情報の収集・分析活動を行っていたが、アメリカの国防予算と海外展開兵力の削減によって施設は閉鎖され、飛行場部分は1972年（昭和47年）、雁ノ巣空軍施設全域は1977年（昭和52年）に返還された。',
#   'Brady Air Base',
#   '戦後はアメリカ軍に接収され「ブレディ飛行場」（',
#   '1433805'],
#  ['・西戸崎通信施設の三施設を統合し、「雁ノ巣空軍施設」（Gannosu Air Station、施設番号・FAC 5005）として在日米軍に提供することが合意された。また、朝鮮戦争後は一時的措置として自衛隊が落下傘降下訓練に使用したほか、西日本空輸や福岡県警などのレシプロ機やヘリコプターが滑走路や格納庫の一部を共同使用していた。1965年（昭和40年）から飛行場区域内に通信傍受用の大型アンテナとオペレーション施設の建設が始まり、共同使用の停止とともに滑走路の舗装が撤去されたため、事実上飛行場としての機能は終焉した。通信施設は1966年（昭和41年）2月に完成し、第14陸軍保安局フィールドステーション（14th U.S. Army Security Agency Field Station）、海軍保安群博多部隊（Naval Security Group Activity, Hakata）、空軍第6918保安中隊（Air Force Security Service 6918th Security Squadron）などアメリカ3軍の諜報部隊が共同で北朝鮮方面の軍事（電波）情報の収集・分析活動を行っていたが、アメリカの国防予算と海外展開兵力の削減によって施設は閉鎖され、飛行場部分は1972年（昭和47年）、雁ノ巣空軍施設全域は1977年（昭和52年）に返還された。',
#   'ブレディ飛行場',
#   '戦後はアメリカ軍に接収され「ブレディ飛行場」（Brady Air Base、施設番号・FAC 5006）の名称で主に輸送部隊の飛行場として使用されたが、1961年（昭和36年）の日米合同委員会でキャンプ博多・',
#   '1433805'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '福岡県糟屋郡和白村', '', '2033406'],
#  ['に設置した飛行場。通称雁ノ巣飛行場。最盛期には大日本航空によって朝鮮、台湾、中華民国、東南アジアへの路線も開設され、戦前における日本最大の民間国際空港であった。',
#   '福岡県糟屋郡和白村（現在の福岡市東区）雁ノ巣',
#   '福岡第一飛行場（ふくおかだいいちひこうじょう）はかつて航空局が',
#   '2033406'],
#  ['があったが陸上機の運用が可能な飛行場が求められたため、市周辺より候補地を選定・調査、[1]1934年（昭和9年）雁ノ巣に決定された。',
#   '名島水上飛行場',
#   '1930年（昭和5年）7月、福岡（大刀洗飛行場）-東京（立川飛行場）間に定期旅客航空路が設けられたが、大刀洗飛行場は福岡市街地より1時間程度を要し利便性が低かった。当時福岡市近辺には水上機専用の',
#   '2381919'],
#  [' Hang Nadim International Airport',
#   'Bandar Udara Internasional Hang Nadim',
#   '\t\t\t\tハン・ナディム国際空港',
#   '3001330'],
#  ['',
#   'Hang Nadim International Airport',
#   '\t\t\t\tハン・ナディム国際空港Bandar Udara Internasional Hang Nadim ',
#   '3001330'],
#  ['）は、インドネシア・リアウ諸島州のバタム島に位置する空港である。',
#   'Hang Nadim International Airport',
#   'ハン・ナディム国際空港（ハン・ナディムこくさいくうこう、英: ',
#   '3001330'],
#  ['所在地', 'インドネシア共和国', '25x20px\xa0', '100'],
#  ['・リアウ諸島州のバタム島に位置する空港である。',
#   'インドネシア',
#   'ハン・ナディム国際空港（ハン・ナディムこくさいくうこう、英: Hang Nadim International Airport）は、',
#   '100'],
#  ['の空港では最長である。本来の目的であるチャンギ国際空港からのダイバートの他に、メッカへの巡礼フライト(ハッジ)などで普段は定期便で飛来しないボーイング747などのチャーター便が運行されている。',
#   'インドネシア',
#   '直線距離で約30km離れているシンガポール・チャンギ国際空港の代替空港として開発された経緯があり、滑走路長は4,040mと',
#   '100'],
#  ['・マレーシア・シンガポール 成長三角地帯の中に位置し、当空港から半径80kmのエリアには、チャンギ国際空港の他に、ジョホールバルのスナイ国際空港(マレーシア)・セレター空港(シンガポール)・ビンタン島のラジャ・ハジ・フィサビッリラー空港がある。(ただし、セレター空港は定期旅客便なし)',
#   'インドネシア',
#   '',
#   '100'],
#  ['母都市', 'バタム島', '', '1260293'],
#  ['に位置する空港である。',
#   'リアウ諸島州のバタム島',
#   'ハン・ナディム国際空港（ハン・ナディムこくさいくうこう、英: Hang Nadim International Airport）は、インドネシア・',
#   '1260293'],
#  ['運営者', 'バタム島', '', '1260293'],
#  ['の代替空港として開発された経緯があり、滑走路長は4,040mとインドネシアの空港では最長である。本来の目的であるチャンギ国際空港からのダイバートの他に、メッカへの巡礼フライト(ハッジ)などで普段は定期便で飛来しないボーイング747などのチャーター便が運行されている。',
#   'チャンギ国際空港',
#   '直線距離で約30km離れているシンガポール・',
#   '126902'],
#  ['からのダイバートの他に、メッカへの巡礼フライト(ハッジ)などで普段は定期便で飛来しないボーイング747などのチャーター便が運行されている。',
#   'チャンギ国際空港',
#   '直線距離で約30km離れているシンガポール・チャンギ国際空港の代替空港として開発された経緯があり、滑走路長は4,040mとインドネシアの空港では最長である。本来の目的である',
#   '126902'],
#  ['の他に、ジョホールバルのスナイ国際空港(マレーシア)・セレター空港(シンガポール)・ビンタン島のラジャ・ハジ・フィサビッリラー空港がある。(ただし、セレター空港は定期旅客便なし)',
#   'チャンギ国際空港',
#   'インドネシア・マレーシア・シンガポール 成長三角地帯の中に位置し、当空港から半径80kmのエリアには、',
#   '126902'],
#  ['(マレーシア)・セレター空港(シンガポール)・ビンタン島のラジャ・ハジ・フィサビッリラー空港がある。(ただし、セレター空港は定期旅客便なし)',
#   'スナイ国際空港',
#   'インドネシア・マレーシア・シンガポール 成長三角地帯の中に位置し、当空港から半径80kmのエリアには、チャンギ国際空港の他に、ジョホールバルの',
#   '526639'],
#  ['(シンガポール)・ビンタン島のラジャ・ハジ・フィサビッリラー空港がある。(ただし、セレター空港は定期旅客便なし)',
#   'セレター空港',
#   'インドネシア・マレーシア・シンガポール 成長三角地帯の中に位置し、当空港から半径80kmのエリアには、チャンギ国際空港の他に、ジョホールバルのスナイ国際空港(マレーシア)・',
#   '210271'],
#  ['がある。(ただし、セレター空港は定期旅客便なし)',
#   'ラジャ・ハジ・フィサビッリラー空港',
#   'インドネシア・マレーシア・シンガポール 成長三角地帯の中に位置し、当空港から半径80kmのエリアには、チャンギ国際空港の他に、ジョホールバルのスナイ国際空港(マレーシア)・セレター空港(シンガポール)・ビンタン島の',
#   '3407002'],
#  ['は定期旅客便なし)',
#   'セレター空港',
#   'インドネシア・マレーシア・シンガポール 成長三角地帯の中に位置し、当空港から半径80kmのエリアには、チャンギ国際空港の他に、ジョホールバルのスナイ国際空港(マレーシア)・セレター空港(シンガポール)・ビンタン島のラジャ・ハジ・フィサビッリラー空港がある。(ただし、',
#   '210271'],
#  ['', 'Rishiri Airport', '\t\t\t\t利尻空港', '150417'],
#  ['）は、北海道利尻郡利尻富士町（利尻島）にある地方管理空港 である。',
#   'Rishiri Airport',
#   '利尻空港（りしりくうこう、英: ',
#   '150417'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '北海道利尻富士町', '', '47538'],
#  ['（利尻島）にある地方管理空港 である。',
#   '北海道利尻郡利尻富士町',
#   '利尻空港（りしりくうこう、英: Rishiri Airport）は、',
#   '47538'],
#  ['）にある地方管理空港 である。',
#   '利尻島',
#   '利尻空港（りしりくうこう、英: Rishiri Airport）は、北海道利尻郡利尻富士町（',
#   '26306'],
#  ['に位置する北海道内の最初の離島空港である。ジェット機の就航が可能であり、地域経済の活性化及び地域振興、島民の重要な生活基盤施設として期待されている。',
#   '利尻島北端',
#   '利尻空港は',
#   '26306'],
#  ['運用時間', '北海道', '', '436'],
#  ['（同飛行場廃港に因み命名された地域名）に存在した飛行場。700m×600mの転圧滑走路面を持ち、格納庫を1棟備えていた。総面積50ヘクタール[1]。愛国郵便切手寄付金を活用し、寄付建設された事により、命名された[2]。',
#   '釧路市愛国',
#   '\t\t\t\t愛国飛行場（あいこくひこうじょう）とは、',
#   '271603'],
#  [' Diori Hamani International Airport',
#   'Aéroport international Diori Hamani',
#   '\t\t\t\tディオリ・アマニ国際空港',
#   '2104077'],
#  ['',
#   'Diori Hamani International Airport',
#   '\t\t\t\tディオリ・アマニ国際空港Aéroport international Diori Hamani ',
#   '2104077'],
#  ['、英: Diori Hamani International Airport）は、ニジェール共和国の首都ニアメにある国際空港。ニアメ市南東の郊外、国道1号線上に位置している。空港にはニジェール空軍基地が併設されている。空港名は、ニジェールの初代大統領アマニ・ディオリの名に由来している。',
#   'Aéroport international Diori Hamani',
#   'ディオリ・アマニ国際空港（ディオリ・アマニこくさいくうこう、仏: ',
#   '2104077'],
#  ['）は、ニジェール共和国の首都ニアメにある国際空港。ニアメ市南東の郊外、国道1号線上に位置している。空港にはニジェール空軍基地が併設されている。空港名は、ニジェールの初代大統領アマニ・ディオリの名に由来している。',
#   'Diori Hamani International Airport',
#   'ディオリ・アマニ国際空港（ディオリ・アマニこくさいくうこう、仏: Aéroport international Diori Hamani、英: ',
#   '2104077'],
#  ['所在地', 'ニジェール共和国', 'ニジェールの旗 ', '8132'],
#  ['の首都ニアメにある国際空港。ニアメ市南東の郊外、国道1号線上に位置している。空港にはニジェール空軍基地が併設されている。空港名は、ニジェールの初代大統領アマニ・ディオリの名に由来している。',
#   'ニジェール共和国',
#   'ディオリ・アマニ国際空港（ディオリ・アマニこくさいくうこう、仏: Aéroport international Diori Hamani、英: Diori Hamani International Airport）は、',
#   '8132'],
#  ['種類', 'ニアメ', '', '102286'],
#  ['にある国際空港。ニアメ市南東の郊外、国道1号線上に位置している。空港にはニジェール空軍基地が併設されている。空港名は、ニジェールの初代大統領アマニ・ディオリの名に由来している。',
#   'ニアメ',
#   'ディオリ・アマニ国際空港（ディオリ・アマニこくさいくうこう、仏: Aéroport international Diori Hamani、英: Diori Hamani International Airport）は、ニジェール共和国の首都',
#   '102286'],
#  ['標高', '政府', '', '8132'],
#  ['の名に由来している。',
#   'アマニ・ディオリ',
#   'ディオリ・アマニ国際空港（ディオリ・アマニこくさいくうこう、仏: Aéroport international Diori Hamani、英: Diori Hamani International Airport）は、ニジェール共和国の首都ニアメにある国際空港。ニアメ市南東の郊外、国道1号線上に位置している。空港にはニジェール空軍基地が併設されている。空港名は、ニジェールの初代大統領',
#   '1847928'],
#  ['ミジュナロードヌィイ・アエロポールト・リヴィーウ；Lviv International Airport)は、西ウクライナの都市リヴィウにある国際空港である。',
#   'Міжнародний аеропорт "Львів"',
#   'リヴィウ国際空港(ウクライナ語:',
#   '587433'],
#  ['；Lviv International Airport)は、西ウクライナの都市リヴィウにある国際空港である。',
#   'ミジュナロードヌィイ・アエロポールト・リヴィーウ',
#   'リヴィウ国際空港(ウクライナ語:Міжнародний аеропорт "Львів"',
#   '587433'],
#  [')は、西ウクライナの都市リヴィウにある国際空港である。',
#   'Lviv International Airport',
#   'リヴィウ国際空港(ウクライナ語:Міжнародний аеропорт "Львів"ミジュナロードヌィイ・アエロポールト・リヴィーウ；',
#   '587433'],
#  ['所在地', 'ウクライナ', '25x20px\xa0', '8435'],
#  ['、リヴィウ種類', 'リヴィウ州', '', '368415'],
#  ['種類', 'リヴィウ', 'リヴィウ州、', '129237'],
#  ['にある国際空港である。',
#   'リヴィウ',
#   'リヴィウ国際空港(ウクライナ語:Міжнародний аеропорт "Львів"ミジュナロードヌィイ・アエロポールト・リヴィーウ；Lviv International Airport)は、西ウクライナの都市',
#   '129237'],
#  ['', 'مطار الغردقة الدولي', '\t\t\t\tフルガダ国際空港', '2125494'],
#  ['\u200e、英語: Hurghada International Airport）はエジプトのフルガダにある国際空港。フルガダの旧市街にあたるエル・ダハール地区から南西に5kmの地点にある。',
#   'مطار الغردقة الدولي',
#   '空港の一覧テンプレートを表示フルガダ国際空港（アラビア語: ',
#   '2125494'],
#  ['）はエジプトのフルガダにある国際空港。フルガダの旧市街にあたるエル・ダハール地区から南西に5kmの地点にある。',
#   'Hurghada International Airport',
#   '空港の一覧テンプレートを表示フルガダ国際空港（アラビア語: مطار الغردقة الدولي\u200e、英語: ',
#   '2125494'],
#  ['所在地', 'エジプト', '25x20px\xa0', '49'],
#  ['のフルガダにある国際空港。フルガダの旧市街にあたるエル・ダハール地区から南西に5kmの地点にある。',
#   'エジプト',
#   '空港の一覧テンプレートを表示フルガダ国際空港（アラビア語: مطار الغردقة الدولي\u200e、英語: Hurghada International Airport）は',
#   '49'],
#  ['種類', 'フルガダ', '', '2083600'],
#  ['にある国際空港。フルガダの旧市街にあたるエル・ダハール地区から南西に5kmの地点にある。',
#   'フルガダ',
#   '空港の一覧テンプレートを表示フルガダ国際空港（アラビア語: مطار الغردقة الدولي\u200e、英語: Hurghada International Airport）はエジプトの',
#   '2083600'],
#  ['標高', '政府', '', '49'],
#  ['Zamboanga International Airport',
#   'Paliparang Pandaigdig ng Zamboanga',
#   '\t\t\t\tサンボアンガ国際空港',
#   '1039537'],
#  ['rt',
#   'po',
#   '\t\t\t\tサンボアンガ国際空港Paliparang Pandaigdig ng ZamboangaZamboanga International Air',
#   '1039537'],
#  ['port）は、フィリピン共和国の南部サンボアンガ市にある国際空港。',
#   'Zamboanga International Air',
#   'サンボアンガ国際空港（サンボアンガこくさいくうこう、英: ',
#   '1039537'],
#  ['所在地', 'フィリピン共和国', 'フィリピンの旗 ', '252152'],
#  ['の南部サンボアンガ市にある国際空港。',
#   'フィリピン共和国',
#   'サンボアンガ国際空港（サンボアンガこくさいくうこう、英: Zamboanga International Airport）は、',
#   '252152'],
#  ['種類', 'サンボアンガ市', '', '915544'],
#  ['にある国際空港。',
#   'サンボアンガ市',
#   'サンボアンガ国際空港（サンボアンガこくさいくうこう、英: Zamboanga International Airport）は、フィリピン共和国の南部',
#   '915544'],
#  [' Aden Adde International Airport',
#   'Garoonka Caalamiga Ee Aadan Cadde',
#   '\t\t\t\tアデン・アッデ国際空港',
#   '1657333'],
#  ['',
#   'Aden Adde International Airport',
#   '\t\t\t\tアデン・アッデ国際空港Garoonka Caalamiga Ee Aadan Cadde ',
#   '1657333'],
#  [',アラビア語: مطار آدم عدي الدولي\u200e）とは、ソマリア連邦共和国の首都モガディシュにある国際空港である。以前はモガディシュ国際空港と呼ばれたが、2007年にソマリア連邦共和国の初代大統領アデン・アブドラ・ウスマンが没した際、ウスマンを記念して現在の空港名に改名した。',
#   'Garoonka Caalamiga Ee Aadan Cadde',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: ',
#   '1657333'],
#  ['\u200e）とは、ソマリア連邦共和国の首都モガディシュにある国際空港である。以前はモガディシュ国際空港と呼ばれたが、2007年にソマリア連邦共和国の初代大統領アデン・アブドラ・ウスマンが没した際、ウスマンを記念して現在の空港名に改名した。',
#   'مطار آدم عدي الدولي',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: Garoonka Caalamiga Ee Aadan Cadde,アラビア語: ',
#   '1657333'],
#  ['と呼ばれたが、2007年にソマリア連邦共和国の初代大統領アデン・アブドラ・ウスマンが没した際、ウスマンを記念して現在の空港名に改名した。',
#   'モガディシュ国際空港',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: Garoonka Caalamiga Ee Aadan Cadde,アラビア語: مطار آدم عدي الدولي\u200e）とは、ソマリア連邦共和国の首都モガディシュにある国際空港である。以前は',
#   '1657333'],
#  ['所在地', 'ソマリア連邦共和国', 'ソマリアの旗 ', '6382'],
#  ['の首都モガディシュにある国際空港である。以前はモガディシュ国際空港と呼ばれたが、2007年にソマリア連邦共和国の初代大統領アデン・アブドラ・ウスマンが没した際、ウスマンを記念して現在の空港名に改名した。',
#   'ソマリア連邦共和国',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: Garoonka Caalamiga Ee Aadan Cadde,アラビア語: مطار آدم عدي الدولي\u200e）とは、',
#   '6382'],
#  ['の初代大統領アデン・アブドラ・ウスマンが没した際、ウスマンを記念して現在の空港名に改名した。',
#   'ソマリア連邦共和国',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: Garoonka Caalamiga Ee Aadan Cadde,アラビア語: مطار آدم عدي الدولي\u200e）とは、ソマリア連邦共和国の首都モガディシュにある国際空港である。以前はモガディシュ国際空港と呼ばれたが、2007年に',
#   '6382'],
#  ['種類', 'ベナディール州モガディシュ', '', '128466'],
#  ['にある国際空港である。以前はモガディシュ国際空港と呼ばれたが、2007年にソマリア連邦共和国の初代大統領アデン・アブドラ・ウスマンが没した際、ウスマンを記念して現在の空港名に改名した。',
#   'モガディシュ',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: Garoonka Caalamiga Ee Aadan Cadde,アラビア語: مطار آدم عدي الدولي\u200e）とは、ソマリア連邦共和国の首都',
#   '128466'],
#  ['が没した際、ウスマンを記念して現在の空港名に改名した。',
#   'アデン・アブドラ・ウスマン',
#   'アデン・アッデ国際空港（アデン・アッデこくさいくうこう,ソマリ語: Garoonka Caalamiga Ee Aadan Cadde,アラビア語: مطار آدم عدي الدولي\u200e）とは、ソマリア連邦共和国の首都モガディシュにある国際空港である。以前はモガディシュ国際空港と呼ばれたが、2007年にソマリア連邦共和国の初代大統領',
#   '1224520'],
#  ['', '二连浩特赛乌苏国际机场', '\t\t\t\tエレンホト・サイウス国際空港', '3608524'],
#  ['拼音：', '二连浩特赛乌苏国际机场', '', '3608524'],
#  ['テンプレートを表示', 'Erenhot Saiwusu International Airport', '', '3608524'],
#  ['、英語: Erenhot Saiwusu International Airport）は、中華人民共和国内モンゴル自治区エレンホト市にある空港である。',
#   '二连浩特赛乌苏国际机场',
#   'エレンホト・サイウス国際空港（中国語: ',
#   '3608524'],
#  ['）は、中華人民共和国内モンゴル自治区エレンホト市にある空港である。',
#   'Erenhot Saiwusu International Airport',
#   'エレンホト・サイウス国際空港（中国語: 二连浩特赛乌苏国际机场、英語: ',
#   '3608524'],
#  ['内モンゴル自治区エレンホト市にある空港である。',
#   '中華人民共和国',
#   'エレンホト・サイウス国際空港（中国語: 二连浩特赛乌苏国际机场、英語: Erenhot Saiwusu International Airport）は、',
#   '1903'],
#  ['座標', '内モンゴル自治区エレンホト市', '', '581219'],
#  ['にある空港である。',
#   '内モンゴル自治区エレンホト市',
#   'エレンホト・サイウス国際空港（中国語: 二连浩特赛乌苏国际机场、英語: Erenhot Saiwusu International Airport）は、中華人民共和国',
#   '581219'],
#  ['',
#   'Aeropuerto de Málaga-Costa del Sol',
#   '\t\t\t\tマラガ＝コスタ・デル・ソル空港',
#   '2002923'],
#  ['）は、スペインアンダルシア州マラガ県の県都であるマラガにある空港。マラガから南西約8Kmに位置する。別名パブロ･ルイス･ピカソ国際空港[2]と呼ばれている。',
#   'Aeropuerto de Málaga-Costa del Sol',
#   'マラガ＝コスタ・デル・ソル空港（西: ',
#   '2002923'],
#  ['[2]と呼ばれている。',
#   'パブロ･ルイス･ピカソ国際空港',
#   'マラガ＝コスタ・デル・ソル空港（西: Aeropuerto de Málaga-Costa del Sol）は、スペインアンダルシア州マラガ県の県都であるマラガにある空港。マラガから南西約8Kmに位置する。別名',
#   '2002923'],
#  ['」もしくは「García Morato」と呼ばれていたが、1965年の省令によって正式に「マラガ空港」と命名され、2011年の省令で「マラガ＝コスタ・デル・ソル空港」と改名された[3]。1968年に新しいターミナルビルが建設され、便数の増加に伴い1991年には第2ターミナルビルが建設された。第2ターミナルビルはリカルド・ボフィルによって設計され、「パブロ・ルイス・ピカソ」の名が付けられている。2010年にも、観光客の急激な増加に対応するために第3ターミナルビルがオープンしている[4]。',
#   'El Rompedizo',
#   'マラガ＝コスタ・デル・ソル空港は1919年9月1日に開港し、トゥールーズ、バルセロナ、アリカンテ、タンジェおよびカサブランカとの間で定期便が運航された。1937年には軍に接収され空軍基地となったが、1946年には民間に開放されている。空港ははじめ、「',
#   '2002923'],
#  ['」と呼ばれていたが、1965年の省令によって正式に「マラガ空港」と命名され、2011年の省令で「マラガ＝コスタ・デル・ソル空港」と改名された[3]。1968年に新しいターミナルビルが建設され、便数の増加に伴い1991年には第2ターミナルビルが建設された。第2ターミナルビルはリカルド・ボフィルによって設計され、「パブロ・ルイス・ピカソ」の名が付けられている。2010年にも、観光客の急激な増加に対応するために第3ターミナルビルがオープンしている[4]。',
#   'García Morato',
#   'マラガ＝コスタ・デル・ソル空港は1919年9月1日に開港し、トゥールーズ、バルセロナ、アリカンテ、タンジェおよびカサブランカとの間で定期便が運航された。1937年には軍に接収され空軍基地となったが、1946年には民間に開放されている。空港ははじめ、「El Rompedizo」もしくは「',
#   '2002923'],
#  ['」と命名され、2011年の省令で「マラガ＝コスタ・デル・ソル空港」と改名された[3]。1968年に新しいターミナルビルが建設され、便数の増加に伴い1991年には第2ターミナルビルが建設された。第2ターミナルビルはリカルド・ボフィルによって設計され、「パブロ・ルイス・ピカソ」の名が付けられている。2010年にも、観光客の急激な増加に対応するために第3ターミナルビルがオープンしている[4]。',
#   'マラガ空港',
#   'マラガ＝コスタ・デル・ソル空港は1919年9月1日に開港し、トゥールーズ、バルセロナ、アリカンテ、タンジェおよびカサブランカとの間で定期便が運航された。1937年には軍に接収され空軍基地となったが、1946年には民間に開放されている。空港ははじめ、「El Rompedizo」もしくは「García Morato」と呼ばれていたが、1965年の省令によって正式に「',
#   '2002923'],
#  ['所在地', 'スペイン', 'スペインの旗 ', '1698826'],
#  ['アンダルシア州マラガ県の県都であるマラガにある空港。マラガから南西約8Kmに位置する。別名パブロ･ルイス･ピカソ国際空港[2]と呼ばれている。',
#   'スペイン',
#   'マラガ＝コスタ・デル・ソル空港（西: Aeropuerto de Málaga-Costa del Sol）は、',
#   '1698826'],
#  ['種類', 'マラガ県マラガ', '', '290815'],
#  ['にある空港。マラガから南西約8Kmに位置する。別名パブロ･ルイス･ピカソ国際空港[2]と呼ばれている。',
#   'アンダルシア州マラガ県の県都であるマラガ',
#   'マラガ＝コスタ・デル・ソル空港（西: Aeropuerto de Málaga-Costa del Sol）は、スペイン',
#   '290815'],
#  ['拠点航空会社', 'Aena', '', '3603955'],
#  ['', 'Okayama Airport', '岡山空港', '54687'],
#  ['）は、岡山県岡山市北区にある地方管理空港。', 'Okayama Airport', '岡山空港（おかやまくうこう、英: ', '54687'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '岡山県岡山市', '', '15700'],
#  ['にある地方管理空港。', '岡山県岡山市北区', '岡山空港（おかやまくうこう、英: Okayama Airport）は、', '1480005'],
#  ['に開設され、1,200mの滑走路を有していたが、地形的に滑走路が延長できずジェット化が不可能であった。このため1988年に、新たに2,000mの滑走路を有する空港として現在地に開港した[3]。その後滑走路は更に延長され、3,000mの滑走路を有する空港となった。旧岡山空港は岡南飛行場へと名前を変更し、セスナ機など小型機専用の空港として存続している。',
#   '岡山市南部',
#   '旧岡山空港は',
#   '15700'],
#  ['に開港。滑走路は2,000 mであった[1]。', '岡山市日応寺', ' 1988年（昭和63年） - ', '15700'],
#  ['へと名前を変更し、セスナ機など小型機専用の空港として存続している。',
#   '岡南飛行場',
#   '旧岡山空港は岡山市南部に開設され、1,200mの滑走路を有していたが、地形的に滑走路が延長できずジェット化が不可能であった。このため1988年に、新たに2,000mの滑走路を有する空港として現在地に開港した[3]。その後滑走路は更に延長され、3,000mの滑走路を有する空港となった。旧岡山空港は',
#   '209693'],
#  ['を併せた収支を県が初めて公表し、2009年度の収支は岡山空港が1億1389万円、岡南飛行場が1億8555万円の赤字であることが明らかになった。',
#   '岡南飛行場',
#   '岡山県が運営する岡山空港は、日本全国の地方空港のなかでは開港前の需要予測を上回った数少ない例とされてきた。しかし、国土交通省の要請により2010年（平成22年）1月24日に',
#   '209693'],
#  ['が1億8555万円の赤字であることが明らかになった。',
#   '岡南飛行場',
#   '岡山県が運営する岡山空港は、日本全国の地方空港のなかでは開港前の需要予測を上回った数少ない例とされてきた。しかし、国土交通省の要請により2010年（平成22年）1月24日に岡南飛行場を併せた収支を県が初めて公表し、2009年度の収支は岡山空港が1億1389万円、',
#   '209693'],
#  ['運用時間', '岡山県', '', '377'],
#  ['', 'Helsinki-Vantaan lentoasema', '\t\t\t\tヘルシンキ・ヴァンター国際空港', '345258'],
#  ['、スウェーデン語：Helsingfors-Vanda flygplats、英語：Helsinki-Vantaa Airport）は、フィンランド共和国のヴァンターにある国際空港である。ヘルシンキ国際空港、バンター空港と呼ばれることもある。',
#   'Helsinki-Vantaan lentoasema',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：',
#   '345258'],
#  ['、英語：Helsinki-Vantaa Airport）は、フィンランド共和国のヴァンターにある国際空港である。ヘルシンキ国際空港、バンター空港と呼ばれることもある。',
#   'Helsingfors-Vanda flygplats',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：Helsinki-Vantaan lentoasema、スウェーデン語：',
#   '345258'],
#  ['）は、フィンランド共和国のヴァンターにある国際空港である。ヘルシンキ国際空港、バンター空港と呼ばれることもある。',
#   'Helsinki-Vantaa Airport',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：Helsinki-Vantaan lentoasema、スウェーデン語：Helsingfors-Vanda flygplats、英語：',
#   '345258'],
#  ['、バンター空港と呼ばれることもある。',
#   'ヘルシンキ国際空港',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：Helsinki-Vantaan lentoasema、スウェーデン語：Helsingfors-Vanda flygplats、英語：Helsinki-Vantaa Airport）は、フィンランド共和国のヴァンターにある国際空港である。',
#   '345258'],
#  ['と呼ばれることもある。',
#   'バンター空港',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：Helsinki-Vantaan lentoasema、スウェーデン語：Helsingfors-Vanda flygplats、英語：Helsinki-Vantaa Airport）は、フィンランド共和国のヴァンターにある国際空港である。ヘルシンキ国際空港、',
#   '345258'],
#  ['所在地', 'フィンランド', '25x20px\xa0', '147836'],
#  ['のヴァンターにある国際空港である。ヘルシンキ国際空港、バンター空港と呼ばれることもある。',
#   'フィンランド共和国',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：Helsinki-Vantaan lentoasema、スウェーデン語：Helsingfors-Vanda flygplats、英語：Helsinki-Vantaa Airport）は、',
#   '147836'],
#  ['母都市', 'ヴァンター', '', '1044388'],
#  ['にある国際空港である。ヘルシンキ国際空港、バンター空港と呼ばれることもある。',
#   'ヴァンター',
#   'ヘルシンキ・ヴァンター国際空港（フィンランド語：Helsinki-Vantaan lentoasema、スウェーデン語：Helsingfors-Vanda flygplats、英語：Helsinki-Vantaa Airport）は、フィンランド共和国の',
#   '1044388'],
#  ['の首都ヘルシンキの北15kmに位置する。フィンランド最大の空港であり、北欧のみならず、中欧や東欧や、アジア各都市へ向けた便のハブ空港として機能している。また、日本と欧州を結ぶ最短飛行距離の空港である上に、乗り継ぎ所要時間も短いため、毎年多くの日本人観光客が利用する。',
#   'フィンランド共和国',
#   '',
#   '147836'],
#  ['種類', 'ヘルシンキ', '', '41492'],
#  ['が手狭になってきたこともあり、1952年にヘルシンキで開催された夏季オリンピックにあわせて開港された。',
#   'ヘルシンキ・マルミ空港',
#   '以前からあった',
#   '1482301'],
#  ['', 'مطار الفجيرة الدول', '\t\t\t\tフジャイラ国際空港', '1157915'],
#  ['、英語：Fujairah International Airport）は、アラブ首長国連邦・フジャイラにある国際空港。',
#   'مطار الفجيرة الدول',
#   'フジャイラ国際空港（アラビア語：',
#   '1157915'],
#  ['）は、アラブ首長国連邦・フジャイラにある国際空港。',
#   'Fujairah International Airport',
#   'フジャイラ国際空港（アラビア語：مطار الفجيرة الدول、英語：',
#   '1157915'],
#  ['所在地', 'アラブ首長国連邦', 'アラブ首長国連邦の旗 ', '6406'],
#  ['・フジャイラにある国際空港。',
#   'アラブ首長国連邦',
#   'フジャイラ国際空港（アラビア語：مطار الفجيرة الدول、英語：Fujairah International Airport）は、',
#   '6406'],
#  ['種類', 'フジャイラ', '', '256889'],
#  ['にある国際空港。',
#   'フジャイラ',
#   'フジャイラ国際空港（アラビア語：مطار الفجيرة الدول、英語：Fujairah International Airport）は、アラブ首長国連邦・',
#   '256889'],
#  [' Katukurunda AirportSLAF Katukurunda',
#   'කටුකුරුන්ද ගුවන්තොටුපළ',
#   'カトゥクルンダ空港',
#   '3522003'],
#  ['SLAF Katukurunda',
#   'Katukurunda Airport',
#   'カトゥクルンダ空港කටුකුරුන්ද ගුවන්තොටුපළ ',
#   '3522003'],
#  ['',
#   'SLAF Katukurunda',
#   'カトゥクルンダ空港කටුකුරුන්ද ගුවන්තොටුපළ Katukurunda Airport',
#   '3522003'],
#  ['、英語: Katukurunda Airport）はスリランカ西部州カルタラ県カルタラ近郊にある空港。',
#   'කටුකුරුන්ද ගුවන්තොටුපළ',
#   'カトゥクルンダ空港（カトゥクルンダくうこう、シンハラ語: ',
#   '3522003'],
#  ['）はスリランカ西部州カルタラ県カルタラ近郊にある空港。',
#   'Katukurunda Airport',
#   'カトゥクルンダ空港（カトゥクルンダくうこう、シンハラ語: කටුකුරුන්ද ගුවන්තොටුපළ、英語: ',
#   '3522003'],
#  ['所在地', 'スリランカ', 'スリランカの旗 ', '4508'],
#  ['西部州カルタラ県カルタラ近郊にある空港。',
#   'スリランカ',
#   'カトゥクルンダ空港（カトゥクルンダくうこう、シンハラ語: කටුකුරුන්ද ගුවන්තොටුපළ、英語: Katukurunda Airport）は',
#   '4508'],
#  ['種類', 'カルタラ', '', '2711339'],
#  ['を担当する空港であり、カルタラ市街地から南東に4.6km程の距離にある。', 'カルタラ', 'カルタラ県の県都', '2711339'],
#  ['開設', 'スリランカ空軍', '', '2580602'],
#  ['', 'Kohnan Airport', '岡南飛行場', '209693'],
#  ['）は、岡山県岡山市南区にある、岡山県が設置・管理する飛行場である。',
#   'Kounan Airport',
#   '岡南飛行場（こうなんひこうじょう、',
#   '209693'],
#  ['であり、全日本空輸による東京への路線をはじめ、東亜国内航空による松山や宮崎への定期旅客路線が就航していた。しかし、1,200mの滑走路ではYS-11クラスの離着陸が限界でジェット化が難しく輸送力増強には限界があったほか、臨海部に存在する、当空港の南東には金甲山（標高403m）や貝殻山（標高209m）が存在するという地形上の理由により滑走路の延長もままならないことから、ジェット化を目指した（新）岡山空港が1988年（昭和63年）岡山市北区の丘陵地帯に建設された。',
#   '岡山空港',
#   'かつての',
#   '253348'],
#  ['として開港する。', '岡山空港', ' 1962年（昭和37年）10月13日 - ', '253348'],
#  ['として開港した当初からエアロコマンダー 500が展示されていたが、新庁舎に移設されることはなく撤去された。',
#   '岡山空港',
#   '2005年まで供用されていた旧ターミナルビルの屋上展望デッキには、',
#   '253348'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '岡山県岡山市南区', '', '1480000'],
#  ['にある、岡山県が設置・管理する飛行場である。',
#   '岡山県岡山市南区',
#   '岡南飛行場（こうなんひこうじょう、Kounan Airport）は、',
#   '1480000'],
#  ['が1988年（昭和63年）岡山市北区の丘陵地帯に建設された。',
#   '岡山空港',
#   'かつての岡山空港であり、全日本空輸による東京への路線をはじめ、東亜国内航空による松山や宮崎への定期旅客路線が就航していた。しかし、1,200mの滑走路ではYS-11クラスの離着陸が限界でジェット化が難しく輸送力増強には限界があったほか、臨海部に存在する、当空港の南東には金甲山（標高403m）や貝殻山（標高209m）が存在するという地形上の理由により滑走路の延長もままならないことから、ジェット化を目指した（新）',
#   '54687'],
#  ['の開港後は、定期旅客航路はそちらに移転し、貸切輸送・遊覧飛行・撮影および宣伝飛行・自家用機に特化した飛行場として、中四国では有数の小型機の拠点となっている。このほか、岡山県警察航空隊・岡山市消防航空隊も当飛行場を基地として使用している。',
#   '岡山空港',
#   '（新）',
#   '54687'],
#  ['供用に伴い岡南飛行場へ名称変更するとともに、種別を「公共用その他飛行場」に変更する。',
#   '岡山空港',
#   ' 1988年（昭和63年）3月11日 - （新）',
#   '54687'],
#  ['運用時間', '岡山県', '', '377'],
#  ['が設置・管理する飛行場である。',
#   '岡山県',
#   '岡南飛行場（こうなんひこうじょう、Kounan Airport）は、岡山県岡山市南区にある、',
#   '377'],
#  ['', 'Noyabrsk Airport', '\t\t\t\tノヤブリスク空港', '2029597'],
#  ['所在地', 'ロシア', 'ロシアの旗 ', '109'],
#  ['ヤマロ・ネネツ自治管区ノヤブリスクに所在する空港。ノヤブリスクの中心街より西に10km程それた場所に所在する。',
#   'ロシア連邦',
#   'ノヤブリスク空港とは、',
#   '109'],
#  ['座標', 'ヤマロ・ネネツ自治管区ノヤブリスク', '', '2029089'],
#  ['に所在する空港。ノヤブリスクの中心街より西に10km程それた場所に所在する。',
#   'ヤマロ・ネネツ自治管区ノヤブリスク',
#   'ノヤブリスク空港とは、ロシア連邦',
#   '2029089'],
#  [' Sultan Hasanuddin International Airport',
#   'Bandar Udara Internasional Sultan Hasanuddin',
#   '\t\t\t\tハサヌディン国際空港',
#   '1463206'],
#  ['',
#   'Sultan Hasanuddin International Airport',
#   '\t\t\t\tハサヌディン国際空港Bandar Udara Internasional Sultan Hasanuddin ',
#   '1463206'],
#  ['、英語: Sultan Hasanuddin International Airport）は、インドネシア・南スラウェシ州の州都であるマカッサル郊外にある国際空港である。インドネシア空軍の基地が併設されている。',
#   'Bandar Udara Internasional Sultan Hasanuddin',
#   'ハサヌディン国際空港 （ハサヌディンこくさいくうこう、インドネシア語: ',
#   '1463206'],
#  ['）は、インドネシア・南スラウェシ州の州都であるマカッサル郊外にある国際空港である。インドネシア空軍の基地が併設されている。',
#   'Sultan Hasanuddin International Airport',
#   'ハサヌディン国際空港 （ハサヌディンこくさいくうこう、インドネシア語: Bandar Udara Internasional Sultan Hasanuddin、英語: ',
#   '1463206'],
#  ['所在地', 'インドネシア共和国', '25x20px\xa0', '100'],
#  ['・南スラウェシ州の州都であるマカッサル郊外にある国際空港である。インドネシア空軍の基地が併設されている。',
#   'インドネシア',
#   'ハサヌディン国際空港 （ハサヌディンこくさいくうこう、インドネシア語: Bandar Udara Internasional Sultan Hasanuddin、英語: Sultan Hasanuddin International Airport）は、',
#   '100'],
#  ['母都市', '南スラウェシ州マカッサル', '', '277453'],
#  ['種類', 'マカッサル', '', '277453'],
#  ['', 'Duxford Aerodrome', '\t\t\t\tダックスフォード飛行場', '1780733'],
#  ['）はイギリスのイングランド東部ケンブリッジシャー・ダックスフォードにある、イギリス空軍とアメリカ陸軍航空軍の航空基地を前身とする飛行場。',
#   'Duxford Aerodrome',
#   'ダックスフォード飛行場（英: ',
#   '1780733'],
#  ['所在地', 'イギリス', 'イギリスの旗 ', '1698893'],
#  ['のイングランド東部ケンブリッジシャー・ダックスフォードにある、イギリス空軍とアメリカ陸軍航空軍の航空基地を前身とする飛行場。',
#   'イギリス',
#   'ダックスフォード飛行場（英: Duxford Aerodrome）は',
#   '1698893'],
#  ['種類', 'ダックスフォード', '', '1685822'],
#  ['にある、イギリス空軍とアメリカ陸軍航空軍の航空基地を前身とする飛行場。',
#   'ケンブリッジシャー・ダックスフォード',
#   'ダックスフォード飛行場（英: Duxford Aerodrome）はイギリスのイングランド東部',
#   '1685822'],
#  ['標高', 'ダックスフォード帝国戦争博物館', '', '1685837'],
#  ['とケンブリッジシャー州政府の共有で、航空管制は同博物館が行っている。',
#   'ダックスフォード帝国戦争博物館',
#   '飛行場の施設は1977年に開設された',
#   '1685837'],
#  ['が開館。', 'ダックスフォード帝国戦争博物館', '1977年、', '1685837'],
#  ['', 'Matsuyama Airport', '松山空港', '61848'],
#  ['）は、愛媛県松山市にある国管理空港。', 'Matsuyama Airport', '松山空港（まつやまくうこう、英: ', '61848'],
#  ['が前身。', '吉田浜飛行場', '広島湾要塞の防空を担うため日本海軍が設営した', '61848'],
#  ['時代の滑走路設備は、現在の滑走路と誘導路の中間に現存している。',
#   '吉田浜飛行場',
#   '太平洋戦争中には9つの航空隊および基地部隊として内海空本部が展開したほか、飛行場北側の敷地には予科練教育隊である松山海軍航空隊が置かれた。軍用飛行場としての名残は、周辺に3基保存されている戦闘機用の掩体壕にも見てとれる。なお、',
#   '61848'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['国内の空港では初の、エプロンルーフの運用を開始する。', '日本', ' 2007年4月 - ', '1864744'],
#  ['種類', '愛媛県松山市', '', '17323'],
#  ['にある国管理空港。', '愛媛県松山市', '松山空港（まつやまくうこう、英: Matsuyama Airport）は、', '17323'],
#  ['運用時間', '国土交通大臣', '', '130177'],
#  ['', '西昌青山机场', '\t\t\t\t西昌青山空港', '3201178'],
#  ['） (IATA: XIC,\xa0ICAO: ZUXC) は中華人民共和国四川省涼山イ族自治州の首都、西昌市にある空港。 2010年2月から拡張工事を行っている[1]。',
#   '西昌青山机场',
#   '西昌青山空港（せいしょうせいざんくうこう、簡体字: ',
#   '3201178'],
#  ['所在地', '中華人民共和国', '中華人民共和国の旗 ', '1903'],
#  ['四川省涼山イ族自治州の首都、西昌市にある空港。 2010年2月から拡張工事を行っている[1]。',
#   '中華人民共和国',
#   '西昌青山空港（せいしょうせいざんくうこう、簡体字: 西昌青山机场） (IATA: XIC,\xa0ICAO: ZUXC) は',
#   '1903'],
#  ['種類', '四川省西昌市', '', '1275053'],
#  ['にある空港。 2010年2月から拡張工事を行っている[1]。',
#   '四川省涼山イ族自治州の首都、西昌市',
#   '西昌青山空港（せいしょうせいざんくうこう、簡体字: 西昌青山机场） (IATA: XIC,\xa0ICAO: ZUXC) は中華人民共和国',
#   '1275053'],
#  ['', 'Kumasi Airport', '\t\t\t\tクマシ空港', '3050557'],
#  ['所在地', 'ガーナ', '25x20px\xa0', '6961'],
#  [' アシャンティ州の州都クマシにある空港[1][2]。ガーナで2番めに大きな空港である。クマシ中心部から約3.5kmに位置する。',
#   'ガーナ',
#   'クマシ空港（Kumasi Airport）は',
#   '6961'],
#  ['で2番めに大きな空港である。クマシ中心部から約3.5kmに位置する。',
#   'ガーナ',
#   'クマシ空港（Kumasi Airport）はガーナ アシャンティ州の州都クマシにある空港[1][2]。',
#   '6961'],
#  ['種類', 'アシャンティ州クマシ', '', '1148074'],
#  ['の州都クマシにある空港[1][2]。ガーナで2番めに大きな空港である。クマシ中心部から約3.5kmに位置する。',
#   'アシャンティ州',
#   'クマシ空港（Kumasi Airport）はガーナ ',
#   '1649956'],
#  ['にある空港[1][2]。ガーナで2番めに大きな空港である。クマシ中心部から約3.5kmに位置する。',
#   'クマシ',
#   'クマシ空港（Kumasi Airport）はガーナ アシャンティ州の州都',
#   '1148074'],
#  ['مطار الملك حسين الدولي King Hussein International Airport',
#   'アカバ・キング・フセイン国際空港',
#   '\t\t\t\t',
#   '604912'],
#  [' King Hussein International Airport',
#   'مطار الملك حسين الدولي',
#   '\t\t\t\tアカバ・キング・フセイン国際空港',
#   '604912'],
#  ['',
#   'King Hussein International Airport',
#   '\t\t\t\tアカバ・キング・フセイン国際空港مطار الملك حسين الدولي ',
#   '604912'],
#  ['（アラビア語：مطار العقبة、英語：Aqaba King Hussein International Airport）は、ヨルダン・ハシミテ王国アカバにある国際空港。この空港の半径15マイル以内には、エジプト、サウジアラビア、イスラエルがあり、非常に政治的に微妙な立地にある。',
#   '・キング・フセイン国際空港',
#   'アカバ',
#   '604912'],
#  ['、英語：Aqaba King Hussein International Airport）は、ヨルダン・ハシミテ王国アカバにある国際空港。この空港の半径15マイル以内には、エジプト、サウジアラビア、イスラエルがあり、非常に政治的に微妙な立地にある。',
#   'مطار العقبة',
#   'アカバ・キング・フセイン国際空港（アラビア語：',
#   '604912'],
#  ['）は、ヨルダン・ハシミテ王国アカバにある国際空港。この空港の半径15マイル以内には、エジプト、サウジアラビア、イスラエルがあり、非常に政治的に微妙な立地にある。',
#   'King Hussein International Airport',
#   'アカバ・キング・フセイン国際空港（アラビア語：مطار العقبة、英語：Aqaba ',
#   '604912'],
#  ['所在地', 'ヨルダン', 'ヨルダンの旗 ', '5935'],
#  ['種類', 'アカバ', '', '203480'],
#  ['にある国際空港。この空港の半径15マイル以内には、エジプト、サウジアラビア、イスラエルがあり、非常に政治的に微妙な立地にある。',
#   'アカバ',
#   'アカバ・キング・フセイン国際空港（アラビア語：مطار العقبة、英語：Aqaba King Hussein International Airport）は、ヨルダン・ハシミテ王国',
#   '203480'],
#  ['',
#   'Erik Nielsen Whitehorse International Airport',
#   '\t\t\t\tエリック・ニールセン・ホワイトホース国際空港',
#   '752174'],
#  ['所在地', 'カナダ', 'カナダの旗 ', '1698830'],
#  ['・ユーコン準州の州都ホワイトホースにある国際空港。ユーコン準州政府が運営している。',
#   'カナダ',
#   'エリック・ニールセン・ホワイトホース国際空港（Erik Nielsen Whitehorse International Airport）は',
#   '1698830'],
#  ['種類', 'ユーコン準州ホワイトホース', '', '687708'],
#  ['にある国際空港。ユーコン準州政府が運営している。',
#   'ユーコン準州の州都ホワイトホース',
#   'エリック・ニールセン・ホワイトホース国際空港（Erik Nielsen Whitehorse International Airport）はカナダ・',
#   '687708'],
#  ['標高', 'ユーコン準州', '', '47739'],
#  ['政府が運営している。',
#   'ユーコン準州',
#   'エリック・ニールセン・ホワイトホース国際空港（Erik Nielsen Whitehorse International Airport）はカナダ・ユーコン準州の州都ホワイトホースにある国際空港。',
#   '47739'],
#  ['', 'Міжнародний аеропорт "Донецьк"', '\t\t\t\tドネツィク国際空港', '3000094'],
#  ['として報道されることもある。2015年12月現在、空港全域は分離独立派のドネツク人民共和国の支配下にあり、戦闘により空港設備は破壊され、航空便は運行されていない。',
#   'ドネツク国際空港',
#   'ドネツィク国際空港（ドネツィクこくさいくうこう）は、ウクライナドネツィク州ドネツィクに存在する国際空港。市街地から見て北西方向約10kmの位置に存在する。日本では',
#   '3000094'],
#  ['所在地', 'ウクライナ', '25x20px\xa0', '8435'],
#  ['ドネツィク州ドネツィクに存在する国際空港。市街地から見て北西方向約10kmの位置に存在する。日本ではドネツク国際空港として報道されることもある。2015年12月現在、空港全域は分離独立派のドネツク人民共和国の支配下にあり、戦闘により空港設備は破壊され、航空便は運行されていない。',
#   'ウクライナ',
#   'ドネツィク国際空港（ドネツィクこくさいくうこう）は、',
#   '8435'],
#  ['種類', 'ドネツィク', '', '380641'],
#  ['に存在する国際空港。市街地から見て北西方向約10kmの位置に存在する。日本ではドネツク国際空港として報道されることもある。2015年12月現在、空港全域は分離独立派のドネツク人民共和国の支配下にあり、戦闘により空港設備は破壊され、航空便は運行されていない。',
#   'ドネツィク州ドネツィク',
#   'ドネツィク国際空港（ドネツィクこくさいくうこう）は、ウクライナ',
#   '380641'],
#  ['', 'El Paso International Airport', '\t\t\t\tエルパソ国際空港', '1009972'],
#  ['）は、アメリカ合衆国テキサス州エルパソ郡にある国際空港。',
#   'El Paso International Airport',
#   'エルパソ国際空港（エルパソこくさいくうこう、英: ',
#   '1009972'],
#  ['所在地', 'アメリカ合衆国', 'アメリカ合衆国の旗 ', '1698838'],
#  ['テキサス州エルパソ郡にある国際空港。',
#   'アメリカ合衆国',
#   'エルパソ国際空港（エルパソこくさいくうこう、英: El Paso International Airport）は、',
#   '1698838'],
#  ['種類', 'テキサス州エルパソ', '', '174233'],
#  ['にある国際空港。',
#   'テキサス州エルパソ郡',
#   'エルパソ国際空港（エルパソこくさいくうこう、英: El Paso International Airport）は、アメリカ合衆国',
#   '2585859'],
#  ['標高', 'エルパソ市', '', '174233'],
#  ['', 'Andijon Xalqaro Aeroporti', '\t\t\t\tアンディジャン国際空港', '2693032'],
#  [')、(IATA: AZN,\xa0ICAO: UTKA) はウズベキスタン・アンディジャン州の州都アンディジャンにある空港である。',
#   'Andizhan Airport',
#   'アンディジャン空港 (英語: ',
#   '2693032'],
#  ['所在地', 'ウズベキスタン', '25x20px\xa0', '13204'],
#  ['・アンディジャン州の州都アンディジャンにある空港である。',
#   'ウズベキスタン',
#   'アンディジャン空港 (英語: Andizhan Airport)、(IATA: AZN,\xa0ICAO: UTKA) は',
#   '13204'],
#  ['種類', 'アンディジャン州アンディジャン', '', '262211'],
#  ['にある空港である。',
#   'アンディジャン州の州都アンディジャン',
#   'アンディジャン空港 (英語: Andizhan Airport)、(IATA: AZN,\xa0ICAO: UTKA) はウズベキスタン・',
#   '262211'],
#  ['標高', 'ウズベキスタン航空', '', '536867'],
#  ['', 'Obihiro Airport', '\t\t\t\t帯広空港', '63174'],
#  ['）は、北海道帯広市の南東部に位置する特定地方管理空港である。国（国土交通省）が設置し、帯広市が管理する。愛称はとかち帯広空港。',
#   'Obihiro Airport',
#   '帯広空港（おびひろくうこう、英: ',
#   '63174'],
#  ['。',
#   'とかち帯広空港',
#   '帯広空港（おびひろくうこう、英: Obihiro Airport）は、北海道帯広市の南東部に位置する特定地方管理空港である。国（国土交通省）が設置し、帯広市が管理する。愛称は',
#   '63174'],
#  ['」とする。', 'とかち帯広空港', ' 2001年6月 - 愛称を「', '63174'],
#  ['として開港する。', '日本陸軍緑ヶ丘飛行場', ' 1937年 - 旧', '63174'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '北海道帯広市', '', '46275'],
#  ['に位置する特定地方管理空港である。国（国土交通省）が設置し、帯広市が管理する。愛称はとかち帯広空港。',
#   '北海道帯広市の南東部',
#   '帯広空港（おびひろくうこう、英: Obihiro Airport）は、',
#   '46275'],
#  ['にて帯広空港として開港する[7]。',
#   '帯広市南町南七線番外地',
#   ' 1964年12月1日 - 第3種F級空港として民間にも供用を開始し、',
#   '46275'],
#  ['）の位置に開港した。帯広市街地が至近にあり利便性に優れた空港であったが、騒音問題や拡張工事が困難であることがジェット機への対応（ジェット化）の障害となっていた[5]ことから、1981年に現在の位置へ移転するとともに、ジェット化が成された。',
#   '十勝飛行場',
#   '1937年、帯広市の西南5 km、現在の帯広駐屯地（',
#   '578290'],
#  ['運用時間', '帯広市', '', '46275'],
#  ['', 'Aeroporto de Congonhas', '\t\t\t\tコンゴーニャス空港', '687667'],
#  ['）は、ブラジルのサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なおコンゴーニャス国際空港の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'Aeroporto de Congonhas',
#   'コンゴーニャス空港（コンゴーニャスくうこう、',
#   '687667'],
#  ['の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'コンゴーニャス国際空港',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、ブラジルのサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なお',
#   '687667'],
#  ['」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'サンパウロ/コンゴーニャス空港',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、ブラジルのサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なおコンゴーニャス国際空港の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「',
#   '687667'],
#  [') に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'Aeroporto de São Paulo/Congonhas',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、ブラジルのサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なおコンゴーニャス国際空港の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (',
#   '687667'],
#  ['」よりも「コンゴーニャス空港」の方が多用されている。',
#   'サンパウロ/コンゴーニャス空港',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、ブラジルのサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なおコンゴーニャス国際空港の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「',
#   '687667'],
#  ['は滑走路が短いため、1960年代以降の長距離国際線の主力機材であった、ボーイング707やダグラス DC-8、そして1970年代に登場したボーイング747やマクドネル・ダグラス DC-10などの、離着陸に2000メートル以上の滑走路長を要する大型機材の就航が不可能な上、市街地にあり滑走路の延長など空港の規模拡張が困難であった。',
#   'コンゴーニャス国際空港',
#   'サンパウロはブラジル最大の都市であるにもかかわらず、上記のように',
#   '687667'],
#  ['の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'コンゴーニャス国際空港',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、ブラジルのサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なお',
#   '687667'],
#  ['は滑走路が短いため、1960年代以降の長距離国際線の主力機材であった、ボーイング707やダグラス DC-8、そして1970年代に登場したボーイング747やマクドネル・ダグラス DC-10などの、離着陸に2000メートル以上の滑走路長を要する大型機材の就航が不可能な上、市街地にあり滑走路の延長など空港の規模拡張が困難であった。',
#   'コンゴーニャス国際空港',
#   'サンパウロはブラジル最大の都市であるにもかかわらず、上記のように',
#   '687667'],
#  ['のサンパウロ市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なおコンゴーニャス国際空港の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'ブラジル',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、',
#   '442519'],
#  ['最大の都市であるサンパウロの市内にあり市内中心部からのアクセスが良好なこともあり、開港当時より現在に至るまでサンパウロの主要空港の1つとして、第二の都市であるリオ・デ・ジャネイロや、ブラジリア、ベロオリゾンテなど、ブラジル各地への国内路線が多数運航されている。',
#   'ブラジル',
#   '',
#   '442519'],
#  ['種類', 'サンパウロ', '', '103900'],
#  ['市内にある空港。サンパウロのIATA都市コードはSAOであるが、IATA空港コードは「CGH」を使用している。なおコンゴーニャス国際空港の名でも知られているが当空港は2008年に国際空港ではなくなっており[4]、空港運営者 Infraero は公式サイト内で空港名を「サンパウロ/コンゴーニャス空港」 (Aeroporto de São Paulo/Congonhas) に変更したと述べているが[5]、こちらの空港サイト（ポルトガル語、英語）では「コンゴーニャス空港」と表記されている。日本語では「サンパウロ/コンゴーニャス空港」よりも「コンゴーニャス空港」の方が多用されている。',
#   'サンパウロ',
#   'コンゴーニャス空港（コンゴーニャスくうこう、Aeroporto de Congonhas）は、ブラジルの',
#   '103900'],
#  ['の市内にあり市内中心部からのアクセスが良好なこともあり、開港当時より現在に至るまでサンパウロの主要空港の1つとして、第二の都市であるリオ・デ・ジャネイロや、ブラジリア、ベロオリゾンテなど、ブラジル各地への国内路線が多数運航されている。',
#   'サンパウロ',
#   'ブラジル最大の都市である',
#   '103900'],
#  ['の主要空港の1つとして、第二の都市であるリオ・デ・ジャネイロや、ブラジリア、ベロオリゾンテなど、ブラジル各地への国内路線が多数運航されている。',
#   'サンパウロ',
#   'ブラジル最大の都市であるサンパウロの市内にあり市内中心部からのアクセスが良好なこともあり、開港当時より現在に至るまで',
#   '103900'],
#  ['の基幹空港の1つ、かつブラジル国内のみならず南アメリカでも有数の規模の乗降客を誇る空港となっている。また、その混雑ぶりから「南半球で最も混雑した空港」との異名をとる。',
#   'サンパウロ',
#   '特にリオ・デ・ジャネイロ市内中心部にあるサントス・デュモン空港との間には、複数の航空会社により、「ポンチ・アエレア」と呼ばれる世界有数の旅客数を持つシャトル便が運航されている。このため、2005年には年間17,147,628人の乗降者数を数えるなど、',
#   '103900'],
#  ['が、さらに1985年にグアルーリョス国際空港がオープンして以降も、内外の複数の航空会社により、ブエノスアイレスやアスンシオン、ラパスなどへの近距離国際線が運航されていたが、現在は運航されていない。',
#   'ヴィラコッポス国際空港',
#   '開港当初から国内線と近距離国際線の両方が運行されており、1960年に',
#   '696558'],
#  ['がオープンして以降も、内外の複数の航空会社により、ブエノスアイレスやアスンシオン、ラパスなどへの近距離国際線が運航されていたが、現在は運航されていない。',
#   'グアルーリョス国際空港',
#   '開港当初から国内線と近距離国際線の両方が運行されており、1960年にヴィラコッポス国際空港が、さらに1985年に',
#   '521895'],
#  ['しかなく、サンパウロから海外へ向かう多くの乗客は、2時間近くかけてコンゴーニャス空港よりバスでヴィラコッポス国際空港に行くか、コンゴーニャス空港で出国手続きを終えた後にリオ・デ・ジャネイロのガレオン国際空港で国際線に乗り継いでおり（なお、フラッグキャリアのヴァリグ・ブラジル航空の長距離国際線は、ヴィラコッポス国際空港ではなくハブが置かれているガレオン国際空港を主に使用していた）、その利便性の低さが問題視されていた。このため、1960年代から市街近郊への新空港建設の必要性が叫ばれていた。',
#   'ヴィラコッポス国際空港',
#   'その上に、長距離国際線にも対応する本格的な国際空港が、市内より100キロ近く離れたカンピーナス市にある',
#   '696558'],
#  ['に行くか、コンゴーニャス空港で出国手続きを終えた後にリオ・デ・ジャネイロのガレオン国際空港で国際線に乗り継いでおり（なお、フラッグキャリアのヴァリグ・ブラジル航空の長距離国際線は、ヴィラコッポス国際空港ではなくハブが置かれているガレオン国際空港を主に使用していた）、その利便性の低さが問題視されていた。このため、1960年代から市街近郊への新空港建設の必要性が叫ばれていた。',
#   'ヴィラコッポス国際空港',
#   'その上に、長距離国際線にも対応する本格的な国際空港が、市内より100キロ近く離れたカンピーナス市にあるヴィラコッポス国際空港しかなく、サンパウロから海外へ向かう多くの乗客は、2時間近くかけてコンゴーニャス空港よりバスで',
#   '696558'],
#  ['ではなくハブが置かれているガレオン国際空港を主に使用していた）、その利便性の低さが問題視されていた。このため、1960年代から市街近郊への新空港建設の必要性が叫ばれていた。',
#   'ヴィラコッポス国際空港',
#   'その上に、長距離国際線にも対応する本格的な国際空港が、市内より100キロ近く離れたカンピーナス市にあるヴィラコッポス国際空港しかなく、サンパウロから海外へ向かう多くの乗客は、2時間近くかけてコンゴーニャス空港よりバスでヴィラコッポス国際空港に行くか、コンゴーニャス空港で出国手続きを終えた後にリオ・デ・ジャネイロのガレオン国際空港で国際線に乗り継いでおり（なお、フラッグキャリアのヴァリグ・ブラジル航空の長距離国際線は、',
#   '696558'],
#  ['が開港した。',
#   'グアルーリョス国際空港',
#   'その後、1970年代に入り、新空港をサンパウロ市北東部のグアルーリョス市にあるブラジル空軍基地を拡張して建設することに決まり、その後1985年1月20日に',
#   '521895'],
#  ['、国内、国際貨物便と格安航空会社はヴィラコッポス国際空港を使用することが多い。',
#   'グアルーリョス国際空港',
#   'その後コンゴーニャス空港への国際線の乗り入れが停止されたこともあり、現在はシャトル便を中心とした国内線はコンゴーニャス空港、国際線とシャトル便以外の国内線は',
#   '521895'],
#  ['を使用することが多い。',
#   'ヴィラコッポス国際空港',
#   'その後コンゴーニャス空港への国際線の乗り入れが停止されたこともあり、現在はシャトル便を中心とした国内線はコンゴーニャス空港、国際線とシャトル便以外の国内線はグアルーリョス国際空港、国内、国際貨物便と格安航空会社は',
#   '696558'],
#  ['やヴィラコッポス国際空港との間にも、リムジンバスや各航空会社運行によるシャトルバスが運行されている。',
#   'グアルーリョス国際空港',
#   '市内中心部と近いことから、タクシーや自家用車でのアクセスの他、サンパウロ市内の主なホテルやバスターミナル、鉄道駅及び地下鉄駅との間には定期バスが高頻度で運行されている。なお、市内バスでの行先にある「AEROPORTO」（空港）行はこの空港を指す。また、',
#   '521895'],
#  ['との間にも、リムジンバスや各航空会社運行によるシャトルバスが運行されている。',
#   'ヴィラコッポス国際空港',
#   '市内中心部と近いことから、タクシーや自家用車でのアクセスの他、サンパウロ市内の主なホテルやバスターミナル、鉄道駅及び地下鉄駅との間には定期バスが高頻度で運行されている。なお、市内バスでの行先にある「AEROPORTO」（空港）行はこの空港を指す。また、グアルーリョス国際空港や',
#   '696558'],
#  ['所在地', 'アメリカ合衆国', 'アメリカ合衆国の旗 ', '1698838'],
#  ['種類', 'ジュノー', '', '426581'],
#  ['は非常に険しい地形が多く、空港を建設することができるような平らな土地はとても貴重なものであった。現在ジュノー国際空港があるのはこうした限られた土地のうちの一ヶ所であるが、同時に多様な生態系をもつ重要な地域でもあり、さまざまな植物や小動物、鳥類のほかにもアメリカグマや数種類のサケ、そしてアメリカ合衆国の国鳥であるハクトウワシも生息していた。最初にこの地に滑走路が敷設されたのは1930年代であるが当時は環境調査などは行われず、また限られたエリアに空港の施設すべてを建設しなければならないためにガスティノー海峡の一部を浚渫するなどしていた。現在でも、アラスカ・マリン・ハイウェイやインサイド・パッセージと呼ばれるアレキサンダー諸島周辺を走る貨物船の航路を除くと、航空機が外部からジュノーへ行くことができる唯一の方法である。このため空港ではシアトルやアンカレッジといった大都市との航空便をはじめヘリコプターや水上機による周辺域への航空機も多く発着しており、過去には小規模な空港でたくさんの交通量を扱うジュノー国際空港の安全性が問題視されたこともあった。この指摘を受けた空港は、「旅客ターミナルを大幅に改良し以後20年の旅客増に対応させる」「空港での安全性を高めるために除雪装置を充実させ充分なスペースを確保する」「滑走路の両端を延長することで滑走路のセーフティエリアを広げ誘導路をアメリカ連邦航空局が定めた基準に適合させる」という3つのプロジェクトを始動させた。',
#   'アラスカ州南東部',
#   '',
#   '3625495'],
#  ['へ行くことができる唯一の方法である。このため空港ではシアトルやアンカレッジといった大都市との航空便をはじめヘリコプターや水上機による周辺域への航空機も多く発着しており、過去には小規模な空港でたくさんの交通量を扱うジュノー国際空港の安全性が問題視されたこともあった。この指摘を受けた空港は、「旅客ターミナルを大幅に改良し以後20年の旅客増に対応させる」「空港での安全性を高めるために除雪装置を充実させ充分なスペースを確保する」「滑走路の両端を延長することで滑走路のセーフティエリアを広げ誘導路をアメリカ連邦航空局が定めた基準に適合させる」という3つのプロジェクトを始動させた。',
#   'ジュノー',
#   'アラスカ州南東部は非常に険しい地形が多く、空港を建設することができるような平らな土地はとても貴重なものであった。現在ジュノー国際空港があるのはこうした限られた土地のうちの一ヶ所であるが、同時に多様な生態系をもつ重要な地域でもあり、さまざまな植物や小動物、鳥類のほかにもアメリカグマや数種類のサケ、そしてアメリカ合衆国の国鳥であるハクトウワシも生息していた。最初にこの地に滑走路が敷設されたのは1930年代であるが当時は環境調査などは行われず、また限られたエリアに空港の施設すべてを建設しなければならないためにガスティノー海峡の一部を浚渫するなどしていた。現在でも、アラスカ・マリン・ハイウェイやインサイド・パッセージと呼ばれるアレキサンダー諸島周辺を走る貨物船の航路を除くと、航空機が外部から',
#   '426581'],
#  ['標高', 'ジュノー郡', '', '426581'],
#  ['', 'Fukue Airport', '\t\t\t\t福江空港', '124558'],
#  ['）は、長崎県五島市にある地方管理空港である。愛称は「五島つばき空港」。「五島福江空港」として案内されることもある。',
#   'Fukue Airport',
#   '福江空港（ふくえくうこう ',
#   '124558'],
#  ['」。「五島福江空港」として案内されることもある。',
#   '五島つばき空港',
#   '福江空港（ふくえくうこう Fukue Airport）は、長崎県五島市にある地方管理空港である。愛称は「',
#   '124558'],
#  ['」として案内されることもある。',
#   '五島福江空港',
#   '福江空港（ふくえくうこう Fukue Airport）は、長崎県五島市にある地方管理空港である。愛称は「五島つばき空港」。「',
#   '124558'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '長崎県五島市上大津町2158', '', '118760'],
#  ['にある地方管理空港である。愛称は「五島つばき空港」。「五島福江空港」として案内されることもある。',
#   '長崎県五島市',
#   '福江空港（ふくえくうこう Fukue Airport）は、',
#   '118760'],
#  ['に位置し[3]、ANAのパイロットは「風向きによっては非常に気流が悪く、経験と技量が必要とされる」と言及している[3]。また当空港はORCが就航する空港としては最南端かつ最西端に位置する。',
#   '福江島の鬼岳中腹',
#   '五島列島最大の島である',
#   '3207233'],
#  ['運用時間', '長崎県', '', '419'],
#  ['Taiwan Taoyuan International Airport', '臺灣桃園國際機場', '台湾桃園国際空港', '1974847'],
#  ['', 'Taiwan Taoyuan International Airport', '台湾桃園国際空港臺灣桃園國際機場', '1974847'],
#  ['滑走路', '臺灣桃園國際機場', '', '1974847'],
#  ['拼音：', '台湾桃园国际机场', '', '1974847'],
#  ['テンプレートを表示', 'Taiwan Taoyuan International Airport', '', '1974847'],
#  ['、英語: Taiwan Taoyuan International Airport）は、台湾（中華民国）桃園市大園区に位置する、台湾最大の国際空港である。',
#   '臺灣桃園國際機場',
#   '台湾桃園国際空港（たいわんとうえんこくさいくうこう、中国語: ',
#   '1974847'],
#  ['）は、台湾（中華民国）桃園市大園区に位置する、台湾最大の国際空港である。',
#   'Taiwan Taoyuan International Airport',
#   '台湾桃園国際空港（たいわんとうえんこくさいくうこう、中国語: 臺灣桃園國際機場、英語: ',
#   '1974847'],
#  ['（台湾桃園国際空港）と改称された[8]。', '台灣桃園國際機場', '2006年9月6日、', '1974847'],
#  ['（台湾桃園国際空港）と改称。', '台灣桃園國際機場', '2006年9月6日00: ', '1974847'],
#  ['（中正国際空港）と改称された（蒋介石の本名は「中正」。「介石」は字）。英語名としては、蒋介石の英語表記(Chiang Kai‐Shek) の頭文字を取った C.K.S. Airport という別称が多用されていた。またチャイナエアラインの機内では、日本語アナウンスで「蒋介石国際空港」と称していた。',
#   '中正國際機場',
#   '当初、十大建設において名称は桃園國際機場（桃園国際空港）と予定されていた。しかし、開港前に中華民国の初代総統である蒋介石を記念して',
#   '1974847'],
#  ['）と改称された（蒋介石の本名は「中正」。「介石」は字）。英語名としては、蒋介石の英語表記(Chiang Kai‐Shek) の頭文字を取った C.K.S. Airport という別称が多用されていた。またチャイナエアラインの機内では、日本語アナウンスで「蒋介石国際空港」と称していた。',
#   '中正国際空港',
#   '当初、十大建設において名称は桃園國際機場（桃園国際空港）と予定されていた。しかし、開港前に中華民国の初代総統である蒋介石を記念して中正國際機場（',
#   '1974847'],
#  [' という別称が多用されていた。またチャイナエアラインの機内では、日本語アナウンスで「蒋介石国際空港」と称していた。',
#   'C.K.S. Airport',
#   '当初、十大建設において名称は桃園國際機場（桃園国際空港）と予定されていた。しかし、開港前に中華民国の初代総統である蒋介石を記念して中正國際機場（中正国際空港）と改称された（蒋介石の本名は「中正」。「介石」は字）。英語名としては、蒋介石の英語表記(Chiang Kai‐Shek) の頭文字を取った ',
#   '1974847'],
#  ['」と称していた。',
#   '蒋介石国際空港',
#   '当初、十大建設において名称は桃園國際機場（桃園国際空港）と予定されていた。しかし、開港前に中華民国の初代総統である蒋介石を記念して中正國際機場（中正国際空港）と改称された（蒋介石の本名は「中正」。「介石」は字）。英語名としては、蒋介石の英語表記(Chiang Kai‐Shek) の頭文字を取った C.K.S. Airport という別称が多用されていた。またチャイナエアラインの機内では、日本語アナウンスで「',
#   '1974847'],
#  ['（中正国際空港）として開港。', '中正國際機場', '1979年2月26日0: ', '1974847'],
#  ['）として開港。', '中正国際空港', '1979年2月26日0: 中正國際機場（', '1974847'],
#  ['（台湾）所在地', '中華民国', '中華民国の旗 ', '279710'],
#  ['）桃園市大園区に位置する、台湾最大の国際空港である。',
#   '中華民国',
#   '台湾桃園国際空港（たいわんとうえんこくさいくうこう、中国語: 臺灣桃園國際機場、英語: Taiwan Taoyuan International Airport）は、台湾（',
#   '279710'],
#  ['母都市', '桃園市大園区', '', '652124'],
#  ['（中華民国）桃園市大園区に位置する、台湾最大の国際空港である。',
#   '台湾',
#   '台湾桃園国際空港（たいわんとうえんこくさいくうこう、中国語: 臺灣桃園國際機場、英語: Taiwan Taoyuan International Airport）は、',
#   '882663'],
#  ['に位置する、台湾最大の国際空港である。',
#   '桃園市大園区',
#   '台湾桃園国際空港（たいわんとうえんこくさいくうこう、中国語: 臺灣桃園國際機場、英語: Taiwan Taoyuan International Airport）は、台湾（中華民国）',
#   '652124'],
#  ['最大の国際空港である。',
#   '台湾',
#   '台湾桃園国際空港（たいわんとうえんこくさいくうこう、中国語: 臺灣桃園國際機場、英語: Taiwan Taoyuan International Airport）は、台湾（中華民国）桃園市大園区に位置する、',
#   '882663'],
#  ['の国際空港としての機能を果たしている。台北松山空港から国際線の業務の移転を目的とし、1979年2月26日に開港した。これにより、松山空港は国内線専用、桃園国際空港は国際線主体で国内線の一部が運航という役割分担がなされるようになったため、国内・国際の航空路線を共に増便することが可能となった。',
#   '台北市',
#   'この空港は、',
#   '20964'],
#  ['に立地する国際空港であることによる。', '台湾の桃園市', '名称は、', '275093'],
#  ['（現在は、桃園市大園区）にあることから、地元である桃園県の職員や民主進歩党を始めとする泛緑連盟の人々の間では以前から桃園国際空港という別称が多用されていた。中国側でも桃園空港と呼ばれる場合が多かった。',
#   '台湾北部にある桃園県大園郷',
#   '同空港は',
#   '652124'],
#  ['）にあることから、地元である桃園県の職員や民主進歩党を始めとする泛緑連盟の人々の間では以前から桃園国際空港という別称が多用されていた。中国側でも桃園空港と呼ばれる場合が多かった。',
#   '桃園市大園区',
#   '同空港は台湾北部にある桃園県大園郷（現在は、',
#   '652124'],
#  ['種類', '台北市', '', '20964'],
#  ['開港', '桃園國際機場股份有限公司', '', '3203641'],
#  ['を記念して中正國際機場（中正国際空港）と改称された（蒋介石の本名は「中正」。「介石」は字）。英語名としては、蒋介石の英語表記(Chiang Kai‐Shek) の頭文字を取った C.K.S. Airport という別称が多用されていた。またチャイナエアラインの機内では、日本語アナウンスで「蒋介石国際空港」と称していた。',
#   '蒋介石',
#   '当初、十大建設において名称は桃園國際機場（桃園国際空港）と予定されていた。しかし、開港前に中華民国の初代総統である',
#   '1797800'],
#  ['である蒋介石を記念して中正國際機場（中正国際空港）と改称された（蒋介石の本名は「中正」。「介石」は字）。英語名としては、蒋介石の英語表記(Chiang Kai‐Shek) の頭文字を取った C.K.S. Airport という別称が多用されていた。またチャイナエアラインの機内では、日本語アナウンスで「蒋介石国際空港」と称していた。',
#   '中華民国の初代総統',
#   '当初、十大建設において名称は桃園國際機場（桃園国際空港）と予定されていた。しかし、開港前に',
#   '59084'],
#  ['', 'Edmonton International Airport', '\t\t\t\tエドモントン国際空港', '245494'],
#  ['所在地', 'カナダ', 'カナダの旗 ', '1698830'],
#  ['の中では5番目、アルバータ州の中で2番目に利用者が多い国際空港である。',
#   'カナダ',
#   'エドモントン国際空港（英: Edmonton International Airport）は',
#   '1698830'],
#  ['母都市', 'アルバータ州', '', '47731'],
#  ['の中で2番目に利用者が多い国際空港である。',
#   'アルバータ州',
#   'エドモントン国際空港（英: Edmonton International Airport）はカナダの中では5番目、',
#   '47731'],
#  ['における主要な旅客および航空貨物を扱う施設であり、アルバータ州北部とカナダの北部地域のハブ空港でもある。2007年に607万人の旅客が利用している。運営はエドモントン空港公団が行っている。',
#   'アルバータ州エドモントン市',
#   '',
#   '355842'],
#  ['種類', 'エドモントン', '', '355842'],
#  ['Aéroport international Mohammed V Mohammed V International Airport',
#   'مطار محمد الخامس الدولي',
#   '\t\t\t\tムハンマド5世国際空港',
#   '540927'],
#  [' Mohammed V International Airport',
#   'Aéroport international Mohammed V',
#   '\t\t\t\tムハンマド5世国際空港مطار محمد الخامس الدولي',
#   '540927'],
#  ['',
#   'Mohammed V International Airport',
#   '\t\t\t\tムハンマド5世国際空港مطار محمد الخامس الدوليAéroport international Mohammed V ',
#   '540927'],
#  ["\u200e, Matar Muhammad al-Khamis ad-Dowaly\u200e、フランス語: L'Aéroport International Mohammed V - Nouasser）は、モロッコ王国のカサブランカにある国際空港。モロッコの国王ムハンマド5世（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。",
#   'العربية: مطار محمد الخامس الدولي',
#   'ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、',
#   '540927'],
#  ["\u200e、フランス語: L'Aéroport International Mohammed V - Nouasser）は、モロッコ王国のカサブランカにある国際空港。モロッコの国王ムハンマド5世（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。",
#   'Matar Muhammad al-Khamis ad-Dowaly',
#   'ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、العربية: مطار محمد الخامس الدولي\u200e, ',
#   '540927'],
#  ['）は、モロッコ王国のカサブランカにある国際空港。モロッコの国王ムハンマド5世（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。',
#   "L'Aéroport International Mohammed V - Nouasser",
#   'ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、العربية: مطار محمد الخامس الدولي\u200e, Matar Muhammad al-Khamis ad-Dowaly\u200e、フランス語: ',
#   '540927'],
#  ['」と呼ぶこともある。1950年代初期から中期にかけて、アメリカ空軍がソビエト連邦に向けて爆撃機を配備していた。1956年にモロッコがフランスから独立した後、当時の国王ムハンマド5世は米軍に撤退を要求した。これに対して、1959年12月に米軍がモロッコからの撤退に応じたため、1963年に米軍はモロッコから完全撤退した。',
#   'ヌアッサー',
#   'もともとアメリカ空軍のヌアッサー空軍基地であった場所に開港した。現在でも地元民は空港のことを郊外の地名である「',
#   '540927'],
#  ['所在地', 'モロッコ', 'モロッコの旗 ', '6378'],
#  ['のカサブランカにある国際空港。モロッコの国王ムハンマド5世（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。',
#   'モロッコ王国',
#   "ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、العربية: مطار محمد الخامس الدولي\u200e, Matar Muhammad al-Khamis ad-Dowaly\u200e、フランス語: L'Aéroport International Mohammed V - Nouasser）は、",
#   '6378'],
#  ['からの撤退に応じたため、1963年に米軍はモロッコから完全撤退した。',
#   'モロッコ',
#   'もともとアメリカ空軍のヌアッサー空軍基地であった場所に開港した。現在でも地元民は空港のことを郊外の地名である「ヌアッサー」と呼ぶこともある。1950年代初期から中期にかけて、アメリカ空軍がソビエト連邦に向けて爆撃機を配備していた。1956年にモロッコがフランスから独立した後、当時の国王ムハンマド5世は米軍に撤退を要求した。これに対して、1959年12月に米軍が',
#   '6378'],
#  ['から完全撤退した。',
#   'モロッコ',
#   'もともとアメリカ空軍のヌアッサー空軍基地であった場所に開港した。現在でも地元民は空港のことを郊外の地名である「ヌアッサー」と呼ぶこともある。1950年代初期から中期にかけて、アメリカ空軍がソビエト連邦に向けて爆撃機を配備していた。1956年にモロッコがフランスから独立した後、当時の国王ムハンマド5世は米軍に撤退を要求した。これに対して、1959年12月に米軍がモロッコからの撤退に応じたため、1963年に米軍は',
#   '6378'],
#  ['にある国際空港。モロッコの国王ムハンマド5世（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。',
#   'カサブランカ',
#   "ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、العربية: مطار محمد الخامس الدولي\u200e, Matar Muhammad al-Khamis ad-Dowaly\u200e、フランス語: L'Aéroport International Mohammed V - Nouasser）は、モロッコ王国の",
#   '53883'],
#  ['種類', 'カサブランカ', '', '53883'],
#  ['市内とは空港連絡鉄道で結ばれており、ターミナル1の地下にはモロッコ国鉄アル・ビダウィ線（English版、français版）のムハンマド5世国際空港駅（français版）がある。',
#   'カサブランカ',
#   '',
#   '53883'],
#  ['（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。',
#   'ムハンマド5世',
#   "ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、العربية: مطار محمد الخامس الدولي\u200e, Matar Muhammad al-Khamis ad-Dowaly\u200e、フランス語: L'Aéroport International Mohammed V - Nouasser）は、モロッコ王国のカサブランカにある国際空港。モロッコの国王",
#   '604493'],
#  ['ムハンマド5世（1909年 - 1961年）を記念して命名された。ロイヤル・エア・モロッコなどがハブ空港としている。',
#   '国王',
#   "ムハンマド5世国際空港（ムハンマド5せいこくさいくうこう、العربية: مطار محمد الخامس الدولي\u200e, Matar Muhammad al-Khamis ad-Dowaly\u200e、フランス語: L'Aéroport International Mohammed V - Nouasser）は、モロッコ王国のカサブランカにある国際空港。モロッコの",
#   '21316'],
#  ['', 'Seghe Airport', '\t\t\t\tセゲ空港', '3203918'],
#  ['（English版）は第二次世界大戦中の1943年7月にシービーと海兵隊強襲大隊によって11日間以内の短期間に建設された。飛行場はレンドバとムンダ・ポイントへの上陸に使われた。',
#   'セギ・ポイント飛行場',
#   '',
#   '3203918'],
#  ['所在地', 'ソロモン諸島', 'ソロモン諸島の旗 ', '28484'],
#  ['ニュージョージア島セゲ（Seghe）にある空港。', 'ソロモン諸島', 'セゲ空港（Seghe Airport）は、', '28484'],
#  ['（Seghe）にある空港。', 'ニュージョージア島セゲ', 'セゲ空港（Seghe Airport）は、ソロモン諸島', '1439515'],
#  ['', 'Aeropuerto de Santander', '\t\t\t\tサンタンデール空港', '2975425'],
#  [', (IATA: SDR,\xa0ICAO: LEXJ))は、スペイン・カンタブリア州・サンタンデール郊外にある国際空港。カンタブリア州唯一の空港である。',
#   'Aeropuerto de Santander',
#   'サンタンデール空港(スペイン語: ',
#   '2975425'],
#  ['所在地', 'スペイン', 'スペインの旗 ', '1698826'],
#  ['・カンタブリア州・サンタンデール郊外にある国際空港。カンタブリア州唯一の空港である。',
#   'スペイン',
#   'サンタンデール空港(スペイン語: Aeropuerto de Santander, (IATA: SDR,\xa0ICAO: LEXJ))は、',
#   '1698826'],
#  ['母都市', 'カンタブリア州カマルゴ・マリアーニョ', '', '60672'],
#  ['唯一の空港である。',
#   'カンタブリア州',
#   'サンタンデール空港(スペイン語: Aeropuerto de Santander, (IATA: SDR,\xa0ICAO: LEXJ))は、スペイン・カンタブリア州・サンタンデール郊外にある国際空港。',
#   '60672'],
#  ['種類', 'サンタンデール', '', '533282'],
#  ['標高', 'AENA', '', '3603955'],
#  ['', 'Okushiri Airport', '\t\t\t\t奥尻空港', '150420'],
#  ['）は、北海道奥尻町（奥尻島）にある地方管理空港 である。',
#   'Okushiri Airport',
#   '奥尻空港（おくしりくうこう、英: ',
#   '150420'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['種類', '北海道奥尻町', '', '181680'],
#  ['（奥尻島）にある地方管理空港 である。',
#   '北海道奥尻町',
#   '奥尻空港（おくしりくうこう、英: Okushiri Airport）は、',
#   '181680'],
#  ['）にある地方管理空港 である。',
#   '奥尻島',
#   '奥尻空港（おくしりくうこう、英: Okushiri Airport）は、北海道奥尻町（',
#   '26307'],
#  ['に位置する離島空港であり、また北海道最西端の空港でもある。北海道南西沖地震で街ごと大津波に襲われた青苗地区の近くに位置する。奥尻島の空の玄関口として観光を中心とした地域振興を支える拠点の一つとしての役割が期待されている。',
#   '奥尻島の南部',
#   '奥尻空港は、',
#   '26307'],
#  ['の空港でもある。北海道南西沖地震で街ごと大津波に襲われた青苗地区の近くに位置する。奥尻島の空の玄関口として観光を中心とした地域振興を支える拠点の一つとしての役割が期待されている。',
#   '北海道最西端',
#   '奥尻空港は、奥尻島の南部に位置する離島空港であり、また',
#   '436'],
#  ['の空の玄関口として観光を中心とした地域振興を支える拠点の一つとしての役割が期待されている。',
#   '奥尻島',
#   '奥尻空港は、奥尻島の南部に位置する離島空港であり、また北海道最西端の空港でもある。北海道南西沖地震で街ごと大津波に襲われた青苗地区の近くに位置する。',
#   '26307'],
#  ['運用時間', '北海道', '', '436'],
#  [' Kuala Lumpur International Airport',
#   'Lapangan Terbang Antarabangsa Kuala Lumpur',
#   'クアラルンプール国際空港',
#   '124429'],
#  ['',
#   'Kuala Lumpur International Airport',
#   'クアラルンプール国際空港Lapangan Terbang Antarabangsa Kuala Lumpur ',
#   '124429'],
#  ['、英語:  Kuala Lumpur International Airport、 マレー語: Lapangan Terbang Antarabangsa Kuala Lumpur）は、マレーシアのセランゴール州セパン (Sepang) にある国際空港で、同国の空の玄関口である。',
#   'KLIA',
#   'クアラルンプール国際空港（クアラルンプールこくさいくうこう、略称: ',
#   '124429'],
#  ['、 マレー語: Lapangan Terbang Antarabangsa Kuala Lumpur）は、マレーシアのセランゴール州セパン (Sepang) にある国際空港で、同国の空の玄関口である。',
#   'Kuala Lumpur International Airport',
#   'クアラルンプール国際空港（クアラルンプールこくさいくうこう、略称: KLIA、英語:  ',
#   '124429'],
#  ['）は、マレーシアのセランゴール州セパン (Sepang) にある国際空港で、同国の空の玄関口である。',
#   'Lapangan Terbang Antarabangsa Kuala Lumpur',
#   'クアラルンプール国際空港（クアラルンプールこくさいくうこう、略称: KLIA、英語:  Kuala Lumpur International Airport、 マレー語: ',
#   '124429'],
#  ['所在地', 'マレーシア', 'マレーシアの旗 ', '2121942'],
#  ['のセランゴール州セパン (Sepang) にある国際空港で、同国の空の玄関口である。',
#   'マレーシア',
#   'クアラルンプール国際空港（クアラルンプールこくさいくうこう、略称: KLIA、英語:  Kuala Lumpur International Airport、 マレー語: Lapangan Terbang Antarabangsa Kuala Lumpur）は、',
#   '2121942'],
#  ['のフラッグ・キャリアのマレーシア航空と、エアアジアグループのハブ空港になっている。F1マレーシア・グランプリが開催されるセパン・インターナショナル・サーキットが付近にある他、空港内及び空港周辺には乗り継ぎ客用のホテルが複数存在する。',
#   'マレーシア',
#   '',
#   '2121942'],
#  ['の玄関口の役割を終えた。',
#   'マレーシア',
#   'なお、この空港の開港により従来の国際空港であったスルタン・アブドゥル・アジズ・シャー空港は、',
#   '2121942'],
#  ['母都市', 'セランゴール州セパン', '', '1392794'],
#  [' (Sepang) にある国際空港で、同国の空の玄関口である。',
#   'セランゴール州セパン',
#   'クアラルンプール国際空港（クアラルンプールこくさいくうこう、略称: KLIA、英語:  Kuala Lumpur International Airport、 マレー語: Lapangan Terbang Antarabangsa Kuala Lumpur）は、マレーシアの',
#   '1392794'],
#  [') にある国際空港で、同国の空の玄関口である。',
#   'Sepang',
#   'クアラルンプール国際空港（クアラルンプールこくさいくうこう、略称: KLIA、英語:  Kuala Lumpur International Airport、 マレー語: Lapangan Terbang Antarabangsa Kuala Lumpur）は、マレーシアのセランゴール州セパン (',
#   '1392794'],
#  ['種類', 'クアラルンプール', '', '93601'],
#  ['中心部から南へ約43km地点に位置する。', 'クアラルンプール', '', '93601'],
#  ['（通称\xa0: スバン空港）に代わる空港として建設がスタートし、1998年6月30日に開港。「森の中の空港、空港の中の森」をコンセプトに、黒川紀章がターミナルビルを含む全体計画を設計し、メインターミナルを大成建設、サテライトを竹中工務店が施工した。実際に周辺はプランテーションされたアブラヤシの森に囲まれている。',
#   'スルタン・アブドゥル・アジズ・シャー空港',
#   'マハティール・ビン・モハマド首相の主導で、これまで運営されていたセランゴール州スバン (Subang) の',
#   '543369'],
#  ['）に代わる空港として建設がスタートし、1998年6月30日に開港。「森の中の空港、空港の中の森」をコンセプトに、黒川紀章がターミナルビルを含む全体計画を設計し、メインターミナルを大成建設、サテライトを竹中工務店が施工した。実際に周辺はプランテーションされたアブラヤシの森に囲まれている。',
#   'スバン空港',
#   'マハティール・ビン・モハマド首相の主導で、これまで運営されていたセランゴール州スバン (Subang) のスルタン・アブドゥル・アジズ・シャー空港（通称\xa0: ',
#   '543369'],
#  ['', 'Aeroporto Internacional de Faro', '\t\t\t\tファロ空港', '3046442'],
#  [', (IATA: FAO,\xa0ICAO: LPFR))は、ポルトガル・ファロにある空港。ファロの西4kmに位置している。2,490mの滑走路1本を有している。',
#   'Aeroporto Internacional de Faro',
#   'ファロ空港（ポルトガル語：',
#   '3046442'],
#  ['所在地', 'ポルトガル', 'ポルトガルの旗 ', '4596'],
#  ['・ファロにある空港。ファロの西4kmに位置している。2,490mの滑走路1本を有している。',
#   'ポルトガル',
#   'ファロ空港（ポルトガル語：Aeroporto Internacional de Faro, (IATA: FAO,\xa0ICAO: LPFR))は、',
#   '4596'],
#  ['運営者', 'ファロ', '', '679275'],
#  ['にある空港。ファロの西4kmに位置している。2,490mの滑走路1本を有している。',
#   'ファロ',
#   'ファロ空港（ポルトガル語：Aeroporto Internacional de Faro, (IATA: FAO,\xa0ICAO: LPFR))は、ポルトガル・',
#   '679275'],
#  [' Supadio Airport', 'Bandar Udara Supadio', '\t\t\t\tスパディオ空港', '3000802'],
#  ['', 'Supadio Airport', '\t\t\t\tスパディオ空港Bandar Udara Supadio ', '3000802'],
#  ['）は、インドネシア・カリマンタン島西部西カリマンタン州のポンティアナックに位置する空港である。',
#   'Supadio Airport',
#   'スパディオ空港（スパディオくうこう、英: ',
#   '3000802'],
#  ['所在地', 'インドネシア共和国', '25x20px\xa0', '100'],
#  ['・カリマンタン島西部西カリマンタン州のポンティアナックに位置する空港である。',
#   'インドネシア',
#   'スパディオ空港（スパディオくうこう、英: Supadio Airport）は、',
#   '100'],
#  ['母都市', '西カリマンタン州ポンティアナック', '', '1288024'],
#  ['に位置する空港である。',
#   'カリマンタン島西部西カリマンタン州のポンティアナック',
#   'スパディオ空港（スパディオくうこう、英: Supadio Airport）は、インドネシア・',
#   '1288024'],
#  ['種類', 'ポンティアナック', '', '1288024'],
#  [' Penang International Airport',
#   'Lapangan Terbang Antarabangsa Pulau Pinang',
#   '\t\t\t\tペナン国際空港',
#   '520085'],
#  ['',
#   'Penang International Airport',
#   '\t\t\t\tペナン国際空港Lapangan Terbang Antarabangsa Pulau Pinang ',
#   '520085'],
#  [', 英語: Penang International Airport） とは、マレーシアのペナン州ペナン島にある国際空港である。',
#   'Lapangan Terbang Antarabangsa Pulau Pinang',
#   'ペナン国際空港 （ペナンこくさいくうこう、マレー語: ',
#   '520085'],
#  ['） とは、マレーシアのペナン州ペナン島にある国際空港である。',
#   'Penang International Airport',
#   'ペナン国際空港 （ペナンこくさいくうこう、マレー語: Lapangan Terbang Antarabangsa Pulau Pinang, 英語: ',
#   '520085'],
#  ['所在地', 'マレーシア', 'マレーシアの旗 ', '2121942'],
#  ['のペナン州ペナン島にある国際空港である。',
#   'マレーシア',
#   'ペナン国際空港 （ペナンこくさいくうこう、マレー語: Lapangan Terbang Antarabangsa Pulau Pinang, 英語: Penang International Airport） とは、',
#   '2121942'],
#  ['種類', 'ペナン州ペナン島', '', '216702'],
#  ['にある国際空港である。',
#   'ペナン州ペナン島',
#   'ペナン国際空港 （ペナンこくさいくうこう、マレー語: Lapangan Terbang Antarabangsa Pulau Pinang, 英語: Penang International Airport） とは、マレーシアの',
#   '216702'],
#  ['）は、岡山県笠岡市にある、かつて農道離着陸場として整備された空港である。1988年にはじまった農林水産省の農道離着陸場整備事業（通称：農道空港）の一つとして建設された。農道空港としての名称は笠岡地区農道離着陸場。',
#   'Kasaoka Airstation',
#   '笠岡ふれあい空港（かさおかふれあいくうこう、英名：',
#   '387734'],
#  ['。',
#   '笠岡地区農道離着陸場',
#   '笠岡ふれあい空港（かさおかふれあいくうこう、英名：Kasaoka Airstation）は、岡山県笠岡市にある、かつて農道離着陸場として整備された空港である。1988年にはじまった農林水産省の農道離着陸場整備事業（通称：農道空港）の一つとして建設された。農道空港としての名称は',
#   '387734'],
#  ['所在地', '日本', '日本の旗 ', '1864744'],
#  ['座標', '岡山県笠岡市', '', '28429'],
#  ['にある、かつて農道離着陸場として整備された空港である。1988年にはじまった農林水産省の農道離着陸場整備事業（通称：農道空港）の一つとして建設された。農道空港としての名称は笠岡地区農道離着陸場。',
#   '岡山県笠岡市',
#   '笠岡ふれあい空港（かさおかふれあいくうこう、英名：Kasaoka Airstation）は、',
#   '28429'],
#  ['', '岡山県笠岡市カブト西町', '所在地\u3000', '28429'],
#  ['', 'Oakland International Airport', '\t\t\t\tオークランド国際空港', '609220'],
#  ['）は、アメリカ合衆国カリフォルニア州アラメダ郡にある国際空港。オークランド中心部から南7kmに位置している。',
#   'Oakland International Airport',
#   'オークランド国際空港（英: ',
#   '609220'],
#  ['所在地', 'アメリカ合衆国', 'アメリカ合衆国の旗 ', '1698838'],
#  ['カリフォルニア州アラメダ郡にある国際空港。オークランド中心部から南7kmに位置している。',
#   'アメリカ合衆国',
#   'オークランド国際空港（英: Oakland International Airport）は、',
#   '1698838'],
#  ['種類', 'カリフォルニア州オークランド', '', '68818'],
#  ['にある国際空港。オークランド中心部から南7kmに位置している。',
#   'カリフォルニア州アラメダ郡',
#   'オークランド国際空港（英: Oakland International Airport）は、アメリカ合衆国',
#   '203364'],
#  ['Dêqên Shangri-La Airport', '迪庆香格里拉机场', '\t\t\t\tデチェン・シャングリラ空港', '2122598'],
#  ['', 'Dêqên Shangri-La Airport', '\t\t\t\tデチェン・シャングリラ空港迪庆香格里拉机场', '2122598'],
#  ['簡体字：', '廸慶香格里拉機場', '', '2122598'],
#  ['拼音：', '迪庆香格里拉机场', '', '2122598'],
#  ['テンプレートを表示', 'Dêqên Shangri-La Airport', '', '2122598'],
#  ['所在地', '中国', '中華人民共和国の旗 ', '1903'],
#  ['雲南省デチェン・チベット族自治州シャングリラ市に位置する4D級の空港。市街からは5km離れている。[5]',
#   '中華人民共和国',
#   'デチェン・シャングリラ空港（－くうこう）は',
#   '1903'],
#  ['種類', '雲南省シャングリラ市', '', '812283'],
#  ['に位置する4D級の空港。市街からは5km離れている。[5]',
#   '雲南省デチェン・チベット族自治州シャングリラ市',
#   'デチェン・シャングリラ空港（－くうこう）は中華人民共和国',
#   '812283']]
